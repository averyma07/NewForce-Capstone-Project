# %%
import tmdbsimple as tmdb
tmdb.API_KEY = '860152e6c4f46e7ea6700b28d6678ae3'
import pandas as pd

# %%
from urllib.error import HTTPError

# %%
movie = tmdb.Movies(603)
response = movie.info()
movie.title
# Out:
# 'The Matrix'

# %%
keywords_animation=[]

# %%
for i in range(1,8):
    keywords_animation += (tmdb.Search().keyword(query='animation', page=i)['results'][:])

# %%
keywords_animation
# Out:
# [{'id': 297442, 'name': 'animation'},
#  {'id': 226430, 'name': 're-animation'},
#  {'id': 343869, 'name': 'animación'},
#  {'id': 339426, 'name': 'kids’ animation'},
#  {'id': 361809, 'name': 'animacion'},
#  {'id': 329905, 'name': 'animatio'},
#  {'id': 239742, 'name': 'model animation'},
#  {'id': 263164, 'name': 'clay animation'},
#  {'id': 298886, 'name': 'rebetiko animation'},
#  {'id': 290380, 'name': 'puppet animation'},
#  {'id': 274047, 'name': 'belgian animation'},
#  {'id': 347464, 'name': 'polish animation'},
#  {'id': 161919, 'name': 'adult animation'},
#  {'id': 239601, 'name': 'european animation'},
#  {'id': 315706, 'name': 'crude animation'},
#  {'id': 326301, 'name': 'animation now'},
#  {'id': 352429, 'name': 'peruvian animation'},
#  {'id': 238726, 'name': 'replacement animation'},
#  {'id': 193149, 'name': 'suspended animation'},
#  {'id': 193521, 'name': 'part animation'},
#  {'id': 334351, 'name': 'brazilian animation'},
#  {'id': 286391, 'name': 'salt animation'},
#  {'id': 243752, 'name': 'cel animation'},
#  {'id': 10159, 'name': 'computer animation'},
#  {'id': 207305, 'name': 'sand animation'},
#  {'id': 335781, 'name': 'mature animation'},
#  {'id': 272027, 'name': 'pornographic animation'},
#  {'id': 289452, 'name': 'wax animation'},
#  {'id': 319969, 'name': 'felt animation'},
#  {'id': 292616, 'name': 'indian animation'},
#  {'id': 302357, 'name': 'animation student'},
#  {'id': 326586, 'name': 'soviet animation'},
#  {'id': 321191, 'name': 'indie animation'},
#  {'id': 295421, 'name': 'plasticine animation'},
#  {'id': 303020, 'name': 'web animation'},
#  {'id': 327308, 'name': 'animal animation'},
#  {'id': 328546, 'name': 'limited animation'},
#  {'id': 290589, 'name': 'western animation'},
#  {'id': 290640, 'name': 'korean animation'},
#  {'id': 257414, 'name': 'object animation'},
#  {'id': 317709, 'name': 'pencil animation'},
#  {'id': 337604, 'name': 'asian animation'},
#  {'id': 239174, 'name': 'silhouette animation'},
#  {'id': 242814, 'name': 'chalk animation'},
#  {'id': 343861, 'name': 'norwegian animation'},
#  {'id': 304996, 'name': 'realistic animation'},
#  {'id': 335950, 'name': 'digital animation'},
#  {'id': 210875, 'name': 'flash animation'},
#  {'id': 353164, 'name': 'israel animation'},
#  {'id': 214793, 'name': 'cutout animation'},
#  {'id': 214794, 'name': 'papercut animation'},
#  {'id': 339053, 'name': 'animation workshop'},
#  {'id': 296721, 'name': 'experimental animation'},
#  {'id': 354903, 'name': 'corrupted animation'},
#  {'id': 354907, 'name': 'animation series'},
#  {'id': 297422, 'name': 'animation director'},
#  {'id': 297423, 'name': 'animation timing'},
#  {'id': 348212, 'name': 'glow animation'},
#  {'id': 348258, 'name': 'bengali animation'},
#  {'id': 357436, 'name': 'independent animation'},
#  {'id': 367675, 'name': 'traditional animation'},
#  {'id': 363217, 'name': 'ia animation'},
#  {'id': 369443, 'name': 'romanian animation'},
#  {'id': 363356, 'name': 'pakistani animation'},
#  {'id': 369963, 'name': 'chinese animation'},
#  {'id': 312092, 'name': 'australian animation'},
#  {'id': 339150, 'name': 'psychedelic animation'},
#  {'id': 332346, 'name': 'akara animation'},
#  {'id': 348469, 'name': 'fan animation'},
#  {'id': 355848, 'name': 'african animation'},
#  {'id': 359958, 'name': 'minimalist animation'},
#  {'id': 361340, 'name': 'test animation'},
#  {'id': 366023, 'name': 'charcoal animation'},
#  {'id': 366067, 'name': 'family animation'},
#  {'id': 367459, 'name': 'doll animation'},
#  {'id': 367506, 'name': 'queer animation'},
#  {'id': 296443, 'name': 'animation documentary'},
#  {'id': 348625, 'name': 'kazakh animation'},
#  {'id': 349703, 'name': 'hungarian animation'},
#  {'id': 361614, 'name': 'procedural animation'},
#  {'id': 339655, 'name': 'british animation'},
#  {'id': 339840, 'name': 'japanese animation'},
#  {'id': 357546, 'name': 'classic animation'},
#  {'id': 295551, 'name': 'authors animation'},
#  {'id': 349821, 'name': 'thriller animation'},
#  {'id': 362469, 'name': 'narrative animation'},
#  {'id': 341557, 'name': 'french animation'},
#  {'id': 369563, 'name': 'animation style'},
#  {'id': 371164, 'name': 'comedy animation'},
#  {'id': 373114, 'name': 'metamorphosis animation'},
#  {'id': 278823, 'name': '3d animation'},
#  {'id': 366485, 'name': '2d animation'},
#  {'id': 357430, 'name': 'children’s animation'},
#  {'id': 243679, 'name': 'sanitation'},
#  {'id': 10122, 'name': 'reanimation'},
#  {'id': 328386, 'name': 'animasyon'},
#  {'id': 319935, 'name': 'agitation'},
#  {'id': 334570, 'name': 'animutation'},
#  {'id': 365773, 'name': 'animazione'},
#  {'id': 360095, 'name': 'avant-garde animation'},
#  {'id': 373113, 'name': 'music-driven animation'},
#  {'id': 294481, 'name': 'animator'},
#  {'id': 282369, 'name': 'animatic'},
#  {'id': 10168, 'name': 'aviation'},
#  {'id': 330350,
#   'name': 'hungarian animation, animation, hungarian, nándor bera'},
#  {'id': 287990, 'name': 'ink paint animation'},
#  {'id': 234662, 'name': 'hand drawn animation'},
#  {'id': 326216, 'name': 'life size animation'},
#  {'id': 293710, 'name': 'wood carve animation'},
#  {'id': 346692, 'name': 'longest animation ever'},
#  {'id': 328042, 'name': 'cut out animation'},
#  {'id': 345895, 'name': 'animation on water'},
#  {'id': 369442, 'name': 'soft pastels animation'},
#  {'id': 362782, 'name': 'french adult animation'},
#  {'id': 366175, 'name': 'toy story animation'},
#  {'id': 370266, 'name': 'horror inde animation'},
#  {'id': 360153, 'name': 'hand painted animation'},
#  {'id': 361400, 'name': 'comic book animation'},
#  {'id': 358482, 'name': 'stop motion animation'},
#  {'id': 356691, 'name': 'hindu mythology animation'},
#  {'id': 333648, 'name': 'among us animation'},
#  {'id': 336583, 'name': 'frame by frame animation'},
#  {'id': 332617, 'name': '-  shin-ei animation (jp)'},
#  {'id': 259583, 'name': 'original video animation (ova)'},
#  {'id': 323096, 'name': 'original net animation (ona)'},
#  {'id': 209220, 'name': 'live action and animation'},
#  {'id': 336941, 'name': 'painted on glass animation'},
#  {'id': 348494, 'name': 'direct animation on negative'},
#  {'id': 332159, 'name': "pakistan's first hand drawn animation"},
#  {'id': 363018, 'name': "cinéma d'animation"},
#  {'id': 356217,
#   'name': 'princess connect! re:dive special animation - fiore storia'}]

# %%
kw_ids_2d = [kw['id'] for kw in keywords_animation if any(w in kw['name'] for w in ['traditional', '2d', 'cel', 'hand drawn', 'ink paint'])]

# %%
kw_ids_2d
# Out:
# [243752, 367675, 366485, 287990, 234662, 332159]

# %%
movies2d = tmdb.Discover().movie(with_genres='16', with_keywords='243752|367675|366485|287990|234662')

# %%
import requests

# %%
mdblist_api_key = 'jdgs0h5ib5jdbf6hc8mphmwa8'

# %%
response = requests.get('https://api.mdblist.com/lists/user?apikey='+mdblist_api_key)

# %%
list_ids = [[mdblist['id'], mdblist['name']] for mdblist in response.json()]

# %%
list_ids[1][0]
# Out:
# 158471

# %%
movies_3d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[0][0]}/items?apikey={mdblist_api_key}')

# %%
movies_3d = movies_3d_response.json()['movies']

# %%
movies_3d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[0][0]}/items?apikey={mdblist_api_key}&offset=1000')

# %%
movies_3d += movies_3d_response.json()['movies']

# %%
movies_3d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[0][0]}/items?apikey={mdblist_api_key}&offset=2000')

# %%
movies_3d += movies_3d_response.json()['movies']

# %%
movies_2d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[1][0]}/items?apikey={mdblist_api_key}')

# %%
movies_2d = movies_2d_response.json()['movies']

# %%
movies_2d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[1][0]}/items?apikey={mdblist_api_key}&offset=1000')

# %%
movies_2d += movies_2d_response.json()['movies']

# %%
movies_2d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[1][0]}/items?apikey={mdblist_api_key}&offset=2000')

# %%
movies_2d += movies_2d_response.json()['movies']

# %%
movies_2d_response = requests.get(f'https://api.mdblist.com/lists/{list_ids[1][0]}/items?apikey={mdblist_api_key}&offset=3000')

# %%
movies_2d += movies_2d_response.json()['movies']

# %%
import pandas as pd

# %%
movies_3d_df = pd.DataFrame(movies_3d)

# %%
movies_3d_df
# Out:
#            id                                                ids  rank  adult  \
# 0      569094  {'imdb': 'tt9362722', 'tmdb': 569094, 'tvdb': ...     1      0
# 1      324857  {'imdb': 'tt4633694', 'tmdb': 324857, 'tvdb': ...     2      0
# 2     1184918  {'imdb': 'tt29623480', 'tmdb': 1184918, 'tvdb'...     3      0
# 3      823219  {'imdb': 'tt4772188', 'tmdb': 823219, 'tvdb': ...     4      0
# 4        2062  {'imdb': 'tt0382932', 'tmdb': 2062, 'tvdb': 53...     5      0
# ...       ...                                                ...   ...    ...
# 2274   729501  {'imdb': 'tr571827', 'tmdb': 729501, 'tvdb': N...  2275      0
# 2275   438247  {'imdb': 'tr284432', 'tmdb': 438247, 'tvdb': N...  2276      0
# 2276   743540  {'imdb': 'tt13334482', 'tmdb': 743540, 'tvdb':...  2277      0
# 2277   737029  {'imdb': 'tt3226448', 'tmdb': 737029, 'tvdb': ...  2278      0
# 2278   719147  {'imdb': 'tr561533', 'tmdb': 719147, 'tvdb': N...  2279      0
#
#                                     title         status country     imdb_id  \
# 0     Spider-Man: Across the Spider-Verse       Released      us   tt9362722
# 1       Spider-Man: Into the Spider-Verse       Released      us   tt4633694
# 2                          The Wild Robot       released      us  tt29623480
# 3                                    Flow       released      lv   tt4772188
# 4                             Ratatouille       Released      us   tt0382932
# ...                                   ...            ...     ...         ...
# 2274                               ROACH™       released      ca    tr571827
# 2275        Doomed: A Biological Cartoon!       released      es    tr284432
# 2276                 Distracted Blueberry       released      ca  tt13334482
# 2277                           Animusic 3  in production      us   tt3226448
# 2278                             Outremer       released      fr    tr561533
#
#       runtime   tvdb_id language mediatype release_date  release_year  \
# 0       140.0  132814.0       en     movie   2023-05-31        2023.0
# 1       117.0      33.0       en     movie   2018-12-06        2018.0
# 2       102.0  353646.0       en     movie   2024-09-12        2024.0
# 3        85.0  356056.0       lv     movie   2024-08-29        2024.0
# 4       111.0     534.0       en     movie   2007-06-28        2007.0
# ...       ...       ...      ...       ...          ...           ...
# 2274     31.0       NaN       en     movie   2022-12-10        2022.0
# 2275     10.0       NaN       en     movie   2011-01-30        2011.0
# 2276    273.0       NaN       fr     movie   2019-10-24        2019.0
# 2277     90.0       NaN       en     movie         None           NaN
# 2278      3.0       NaN       en     movie   2017-09-15        2017.0
#
#      spoken_language
# 0                 en
# 1                 en
# 2                 en
# 3                 xx
# 4                 en
# ...              ...
# 2274            None
# 2275              en
# 2276              fr
# 2277            None
# 2278            None
#
# [2279 rows x 15 columns]

# %%
movies_2d_df = pd.DataFrame(movies_2d)

# %%
movies_3d_df = pd.merge(movies_3d_df, pd.json_normalize(movies_3d_df['ids']), left_index=True, right_index=True).drop(columns='ids')

# %%
movies_2d_df = pd.merge(movies_2d_df, pd.json_normalize(movies_2d_df['ids']), left_index=True, right_index=True).drop(columns='ids')

# %%
movies_2d_df[movies_2d_df.tmdb == 1266996]
# Out:
#            id  rank  adult                          title    status country  \
# 1905  1266996  1906      0  The Dark Knight's First Night  Released      us
#
#         imdb_id  runtime  tvdb_id language mediatype release_date  \
# 1905  tt3366668      2.0      NaN       en     movie   1992-03-16
#
#       release_year spoken_language       imdb     tmdb  tvdb mdblist
# 1905        1992.0              xx  tt3366668  1266996   NaN   3e6va

# %%
movies_3d_df.to_csv('3D_Movies.csv')

# %%
movies_2d_df.to_csv('2D_Movies.csv')

# %%
movies_3d_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2279 entries, 0 to 2278
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2279 non-null   int64
#  1   rank             2279 non-null   int64
#  2   adult            2279 non-null   int64
#  3   title            2279 non-null   object
#  4   status           2279 non-null   object
#  5   country          2246 non-null   object
#  6   imdb_id          2270 non-null   object
#  7   runtime          2269 non-null   float64
#  8   tvdb_id          1240 non-null   float64
#  9   language         2279 non-null   object
#  10  mediatype        2279 non-null   object
#  11  release_date     2226 non-null   object
#  12  release_year     2233 non-null   float64
#  13  spoken_language  1878 non-null   object
#  14  imdb             2270 non-null   object
#  15  tmdb             2279 non-null   int64
#  16  tvdb             1240 non-null   float64
#  17  mdblist          2279 non-null   object
# dtypes: float64(4), int64(4), object(10)
# memory usage: 320.6+ KB

# %%
tmdb_2d = []

# %%
for i, row in movies_2d_df.iterrows():
    try:
        tmdb_2d.append(tmdb.Movies(row['tmdb']).info())
    except:
        continue

# %%
tmdb_2d
# Out:
# [{'adult': False,
#   'backdrop_path': '/dyJvKsNs2KP8qQnAXbRwDjblViy.jpg',
#   'belongs_to_collection': None,
#   'budget': 19000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://gkids.com/films/spirited-away',
#   'id': 129,
#   'imdb_id': 'tt0245429',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '千と千尋の神隠し',
#   'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#   'popularity': 35.0613,
#   'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#   'production_companies': [{'id': 10342,
#     'logo_path': '/uFuxPEZRUcBTEiYIxjHJq62Vr77.png',
#     'name': 'Studio Ghibli',
#     'origin_country': 'JP'},
#    {'id': 1779,
#     'logo_path': '/41nGzTdCnORYZIZzaGZtfsBwQCl.png',
#     'name': 'Tokuma Shoten',
#     'origin_country': 'JP'},
#    {'id': 6755,
#     'logo_path': '/bWiM2iY82B32NGmPCOFatgfekIR.png',
#     'name': 'Nippon Television Network Corporation',
#     'origin_country': 'JP'},
#    {'id': 11847,
#     'logo_path': '/rZP0I1p3hZNUMNFPHUSal6rWThQ.png',
#     'name': 'Mitsubishi',
#     'origin_country': 'JP'},
#    {'id': 1778,
#     'logo_path': '/b5rT6VbYza3LyfltCmz1OcqzWJM.png',
#     'name': 'dentsu',
#     'origin_country': 'JP'},
#    {'id': 1780,
#     'logo_path': '/4Qzhr7FxVtaMwmsh7118G3yvOhO.png',
#     'name': 'TFC',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2001-07-20',
#   'revenue': 274925095,
#   'runtime': 125,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Beyond the tunnel was a mysterious town.',
#   'title': 'Spirited Away',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 18194},
#  {'adult': False,
#   'backdrop_path': '/nB6IR9XfdRpVRKCz85uT97EjgwB.jpg',
#   'belongs_to_collection': {'id': 383987,
#    'name': 'Attack on Titan Collection',
#    'poster_path': '/50rRT2Kf8NQ1zeD2y5KTQDEp8FX.jpg',
#    'backdrop_path': '/f8ruHHptnKb45zMQN5bAKgbSLyw.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 1333100,
#   'imdb_id': 'tt33175825',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '劇場版「進撃の巨人」完結編 THE LAST ATTACK',
#   'overview': 'A colossal-sized omnibus film bringing together the last two episodes of Attack on Titan in the franchise\'s first-ever theatrical experience. After venturing beyond the walls and separated from his comrades, Eren finds himself inspired by this new truth and plots the "Rumbling," a terrifying plan to eradicate every living thing in the world. With the fate of the world hanging in the balance, a motley crew of Eren\'s former comrades and enemies scramble to halt his deadly mission. The only question is, can they stop him?',
#   'popularity': 6.8777,
#   'poster_path': '/wgwldDDlTDDMrluOMkpSA8lyKjv.jpg',
#   'production_companies': [{'id': 21444,
#     'logo_path': '/wSejGn3lAZdQ5muByxvzigwyDY6.png',
#     'name': 'MAPPA',
#     'origin_country': 'JP'},
#    {'id': 9148,
#     'logo_path': '/rtW3NadfF4kR5mTW00ahiFxw6k7.png',
#     'name': 'Pony Canyon',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2024-03-20',
#   'revenue': 21525687,
#   'runtime': 145,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'See for yourself the end of their story.',
#   'title': 'Attack on Titan: THE LAST ATTACK',
#   'video': False,
#   'vote_average': 8.736,
#   'vote_count': 184},
#  {'adult': False,
#   'backdrop_path': '/aHaqZpOL7UyVu0nKqp3SMz0o2E1.jpg',
#   'belongs_to_collection': None,
#   'budget': 3700000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10752, 'name': 'War'}],
#   'homepage': 'https://gkids.com/films/grave-of-the-fireflies',
#   'id': 12477,
#   'imdb_id': 'tt0095327',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '火垂るの墓',
#   'overview': 'In the final months of World War II, 14-year-old Seita and his sister Setsuko are orphaned when their mother is killed during an air raid in Kobe, Japan. After a falling out with their aunt, they move into an abandoned bomb shelter. With no surviving relatives and their emergency rations depleted, Seita and Setsuko struggle to survive.',
#   'popularity': 0.0148,
#   'poster_path': '/k9tv1rXZbOhH7eiCk378x61kNQ1.jpg',
#   'production_companies': [{'id': 10342,
#     'logo_path': '/uFuxPEZRUcBTEiYIxjHJq62Vr77.png',
#     'name': 'Studio Ghibli',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '1988-04-16',
#   'revenue': 842132,
#   'runtime': 89,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Why do fireflies have to die so soon?',
#   'title': 'Grave of the Fireflies',
#   'video': False,
#   'vote_average': 8.4,
#   'vote_count': 6473},
#  {'adult': False,
#   'backdrop_path': '/wGwSWDG3LIQxchg2M8HV7bDqYKU.jpg',
#   'belongs_to_collection': {'id': 1431054,
#    'name': 'Violet Evergarden Collection',
#    'poster_path': '/vdboDPxXs4n7jASXJ5Tb3pdjC8U.jpg',
#    'backdrop_path': '/9Htaft3Aax28UH1c1ui62kqakhQ.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'https://www.netflix.com/title/81193214',
#   'id': 533514,
#   'imdb_id': 'tt8652818',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '劇場版 ヴァイオレット・エヴァーガーデン',
#   'overview': 'As the world moves on from the war and technological advances bring changes to her life, Violet still hopes to see her lost commanding officer again.',
#   'popularity': 7.841,
#   'poster_path': '/bajajkoErDst0JxdFyBkABiF9rW.jpg',
#   'production_companies': [{'id': 5438,
#     'logo_path': '/leZ8GPCL0GneHHayPVnXtB3p0We.png',
#     'name': 'Kyoto Animation',
#     'origin_country': 'JP'},
#    {'id': 86839,
#     'logo_path': '/cnOJAkVVmKZLIzmgw4fRRZ2dctT.png',
#     'name': 'ABC Animation',
#     'origin_country': 'JP'},
#    {'id': 9148,
#     'logo_path': '/rtW3NadfF4kR5mTW00ahiFxw6k7.png',
#     'name': 'Pony Canyon',
#     'origin_country': 'JP'},
#    {'id': 136217,
#     'logo_path': '/dBYuplhBgeOsGPQOI0LukWNbFWE.png',
#     'name': 'Bandai Namco Arts',
#     'origin_country': 'JP'},
#    {'id': 244119,
#     'logo_path': None,
#     'name': 'Rakuonsha',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2020-09-18',
#   'revenue': 20339624,
#   'runtime': 140,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Violet Evergarden: The Movie',
#   'video': False,
#   'vote_average': 8.287,
#   'vote_count': 501},
#  {'adult': False,
#   'backdrop_path': '/2okfik8YwzSfdETpT5cUClSiGFO.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': 'https://gkids.com/films/look-back',
#   'id': 1244492,
#   'imdb_id': 'tt31711040',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'ルックバック',
#   'overview': 'Popular, outgoing Fujino is celebrated by her classmates for her funny comics in the class newspaper. One day, her teacher asks her to share the space with Kyomoto, a truant recluse whose beautiful artwork sparks a competitive fervor in Fujino. What starts as jealousy transforms when Fujino realizes their shared passion for drawing.',
#   'popularity': 9.6644,
#   'poster_path': '/4f2EcNkp1Mvp9wE5w7HKxcmACWg.jpg',
#   'production_companies': [{'id': 136998,
#     'logo_path': '/4Gw6jh3aUoJArMECqQ8ZXV7OjB8.png',
#     'name': 'Studio Durian',
#     'origin_country': 'JP'},
#    {'id': 55938,
#     'logo_path': '/ku5PUEwBjUx8XaYikgaXRVLIMbb.png',
#     'name': 'avex pictures',
#     'origin_country': 'JP'},
#    {'id': 2918,
#     'logo_path': '/gyEWUBWwqrm3H5T2hkERD9LxpOq.png',
#     'name': 'Shueisha',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2024-06-28',
#   'revenue': 12648664,
#   'runtime': 58,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Manga drew them together. Life made them best friends.',
#   'title': 'Look Back',
#   'video': False,
#   'vote_average': 8.0,
#   'vote_count': 525},
#  {'adult': False,
#   'backdrop_path': '/6kqybERm5qi2jGpu8I7DaQPxpSU.jpg',
#   'belongs_to_collection': None,
#   'budget': 7300000,
#   'genres': [{'id': 16, 'name': 'Animation'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': 'http://www.sonypictures.com/classics/persepolis/',
#   'id': 2011,
#   'imdb_id': 'tt0808417',
#   'origin_country': ['FR'],
#   'original_language': 'fr',
#   'original_title': 'Persepolis',
#   'overview': "In 1970s Iran, Marjane 'Marji' Satrapi watches events through her young eyes and her idealistic family of a long dream being fulfilled of the hated Shah's defeat in the Iranian Revolution of 1979. However as Marji grows up, she witnesses first hand how the new Iran, now ruled by Islamic fundamentalists, has become a repressive tyranny on its own.",
#   'popularity': 2.6117,
#   'poster_path': '/aU8i2QAdTyRR1nYb36Gq51xXP8p.jpg',
#   'production_companies': [{'id': 84593,
#     'logo_path': None,
#     'name': "Société des Producteurs de L'Angoa",
#     'origin_country': ''},
#    {'id': 58,
#     'logo_path': '/voYCwlBHJQANtjvm5MNIkCF1dDH.png',
#     'name': 'Sony Pictures Classics',
#     'origin_country': 'US'},
#    {'id': 311,
#     'logo_path': '/TNGvZ8zOklntjPP3EcsHtrR8Rc.png',
#     'name': 'PROCIREP',
#     'origin_country': 'FR'},
#    {'id': 312, 'logo_path': None, 'name': 'Soficinéma', 'origin_country': ''},
#    {'id': 591,
#     'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png',
#     'name': 'France 3 Cinéma',
#     'origin_country': 'FR'},
#    {'id': 744,
#     'logo_path': '/uM3Vrs3TZJJJTyCAPy4zir9IQeC.png',
#     'name': 'Diaphana Films',
#     'origin_country': 'FR'},
#    {'id': 854,
#     'logo_path': None,
#     'name': 'Sofica EuropaCorp',
#     'origin_country': 'FR'},
#    {'id': 860,
#     'logo_path': '/aWrTeKCGu9jjsiiVSDsALC3vxu4.png',
#     'name': 'Celluloid Dreams',
#     'origin_country': 'FR'},
#    {'id': 862,
#     'logo_path': '/vdK6ZhC2CSW36j0VPEavRxOpbEg.png',
#     'name': 'The Kennedy/Marshall Company',
#     'origin_country': 'US'},
#    {'id': 11246,
#     'logo_path': '/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png',
#     'name': 'La Région Île-de-France',
#     'origin_country': 'FR'},
#    {'id': 23677,
#     'logo_path': '/hmZNsmDBAaFAYtPr921IDTKi0aR.png',
#     'name': 'Fondation GAN pour le Cinéma',
#     'origin_country': 'FR'},
#    {'id': 62546,
#     'logo_path': '/tY53okXrorVw7MML5zWiTcwlx4D.png',
#     'name': '2.4.7. Films',
#     'origin_country': 'FR'},
#    {'id': 84592,
#     'logo_path': None,
#     'name': 'French Connection Animations',
#     'origin_country': 'FR'},
#    {'id': 310,
#     'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#     'name': 'CNC',
#     'origin_country': 'FR'}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2007-06-27',
#   'revenue': 0,
#   'runtime': 95,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Persian',
#     'iso_639_1': 'fa',
#     'name': 'فارسی'},
#    {'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}],
#   'status': 'Released',
#   'tagline': "The film Iran didn't want the world to see.",
#   'title': 'Persepolis',
#   'video': False,
#   'vote_average': 7.88,
#   'vote_count': 2135},
#  {'adult': False,
#   'backdrop_path': '/CKGSEnFTpcxPJM5TzTFUJz53s.jpg',
#   'belongs_to_collection': None,
#   'budget': 3400000,
#   'genres': [{'id': 99, 'name': 'Documentary'},
#    {'id': 16, 'name': 'Animation'}],
#   'homepage': 'https://fleemovie.com/',
#   'id': 680813,
#   'imdb_id': 'tt8430054',
#   'origin_country': ['DK'],
#   'original_language': 'da',
#   'original_title': 'Flugt',
#   'overview': 'Recounted mostly through animation to protect his identity, Amin looks back over his past as a child refugee from Afghanistan as he grapples with a secret he’s kept hidden for 20 years.',
#   'popularity': 1.6267,
#   'poster_path': '/vlMIbqOpYG553J1kOJXA7mwQvE6.jpg',
#   'production_companies': [{'id': 29062,
#     'logo_path': '/hwlA6f2HhaOJP1ZcrYL8f8g8UbJ.png',
#     'name': 'Final Cut for Real',
#     'origin_country': 'DK'},
#    {'id': 12430,
#     'logo_path': '/lkWMDyfpBYL1hVnVCd9CvexQqQz.png',
#     'name': 'Vivement lundi !',
#     'origin_country': 'FR'},
#    {'id': 118108,
#     'logo_path': '/4s94doXw4KxBhdChNjwtaSk6Iop.png',
#     'name': 'Sun Creature',
#     'origin_country': 'DK'},
#    {'id': 6735,
#     'logo_path': '/pAQW38WU8ychBvYU2aGPTEbynEN.png',
#     'name': 'Participant',
#     'origin_country': 'US'},
#    {'id': 130146,
#     'logo_path': None,
#     'name': 'MostFilm',
#     'origin_country': 'SE'},
#    {'id': 21979,
#     'logo_path': '/pVdOYVNJracFdcEsDihqz3VSZ0U.png',
#     'name': 'Mer Film',
#     'origin_country': 'NO'},
#    {'id': 239,
#     'logo_path': '/96hCWEsfmTZQsoUap0CcG21qaA.png',
#     'name': 'VPRO',
#     'origin_country': 'NL'},
#    {'id': 149332,
#     'logo_path': '/3pvLAa2Q3bWiRLPgBGokWSRSvWe.png',
#     'name': 'Vice Studios',
#     'origin_country': 'US'},
#    {'id': 73068,
#     'logo_path': '/m669bsYloJvsocBzYlgAftIgVsE.png',
#     'name': 'RYOT Films',
#     'origin_country': 'US'},
#    {'id': 149331,
#     'logo_path': '/bNQ61EvZO1HWvAQKqzVqCqXNqkr.png',
#     'name': 'Left Handed Films',
#     'origin_country': 'GB'},
#    {'id': 201,
#     'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png',
#     'name': 'ARTE',
#     'origin_country': 'FR'},
#    {'id': 28367,
#     'logo_path': '/kw6n8hNwQXQSPlGdwVZvmbO0Haq.png',
#     'name': 'RTV Slovenija',
#     'origin_country': 'SI'},
#    {'id': 45345,
#     'logo_path': '/fb5rZB6gnthrxAeIYlRutKdGzV.png',
#     'name': 'Estonian Public Broadcasting (ERR)',
#     'origin_country': 'EE'},
#    {'id': 851,
#     'logo_path': '/kieSA3GFVysJcAUXNRer06u6e5x.png',
#     'name': 'MEDIA Programme of the European Union',
#     'origin_country': 'BE'},
#    {'id': 47815,
#     'logo_path': '/i083ezPVOG73vFgpE4KkZBuS4KH.png',
#     'name': 'I Wonder Pictures',
#     'origin_country': 'IT'}],
#   'production_countries': [{'iso_3166_1': 'DK', 'name': 'Denmark'},
#    {'iso_3166_1': 'EE', 'name': 'Estonia'},
#    {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#    {'iso_3166_1': 'NO', 'name': 'Norway'},
#    {'iso_3166_1': 'SE', 'name': 'Sweden'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'FI', 'name': 'Finland'},
#    {'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'SI', 'name': 'Slovenia'},
#    {'iso_3166_1': 'ES', 'name': 'Spain'},
#    {'iso_3166_1': 'BE', 'name': 'Belgium'},
#    {'iso_3166_1': 'IT', 'name': 'Italy'}],
#   'release_date': '2021-06-17',
#   'revenue': 712229,
#   'runtime': 89,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Danish',
#     'iso_639_1': 'da',
#     'name': 'Dansk'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'},
#    {'english_name': 'Persian', 'iso_639_1': 'fa', 'name': 'فارسی'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'},
#    {'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'}],
#   'status': 'Released',
#   'tagline': 'Sometimes it takes years to start living your life',
#   'title': 'Flee',
#   'video': False,
#   'vote_average': 7.7,
#   'vote_count': 389},
#  {'adult': False,
#   'backdrop_path': '/3zTbERSBLh7waK9811RTKGAcG86.jpg',
#   'belongs_to_collection': None,
#   'budget': 12000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://gkids.com/films/wolfwalkers',
#   'id': 441130,
#   'imdb_id': 'tt5198068',
#   'origin_country': ['IE', 'LU', 'US'],
#   'original_language': 'en',
#   'original_title': 'Wolfwalkers',
#   'overview': 'In a time of superstition and magic, when wolves are seen as demonic and nature an evil to be tamed, a young apprentice hunter comes to Ireland with her father to wipe out the last pack. But when she saves a wild native girl, their friendship leads her to discover the world of the Wolfwalkers and transform her into the very thing her father is tasked to destroy.',
#   'popularity': 4.7841,
#   'poster_path': '/vqGiNbdc2sDwsnivMMYzwAoSSu6.jpg',
#   'production_companies': [{'id': 23948,
#     'logo_path': '/uneZYGxTZcwAzmPTTaefmDNWPzN.png',
#     'name': 'Cartoon Saloon',
#     'origin_country': 'IE'},
#    {'id': 13351,
#     'logo_path': '/3cHYz3iUqBAnQfPh8LQnEaWSh1w.png',
#     'name': 'Melusine Productions',
#     'origin_country': 'LU'},
#    {'id': 726,
#     'logo_path': '/hHaQQgxqg2NohqZSxbMTB9E483m.png',
#     'name': 'Haut et Court',
#     'origin_country': 'FR'},
#    {'id': 104,
#     'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png',
#     'name': 'Canal+',
#     'origin_country': 'FR'},
#    {'id': 1923,
#     'logo_path': '/ilgktofJY7OsURHfccJrug4GKdQ.png',
#     'name': 'RTÉ',
#     'origin_country': 'IE'},
#    {'id': 11620,
#     'logo_path': '/f3hRdCaK1w9qH1Qs8nLd2L2bae1.png',
#     'name': 'OCS',
#     'origin_country': 'FR'},
#    {'id': 89705,
#     'logo_path': '/9lUhHbMr32wzkDgaOMNrzIu66YC.png',
#     'name': 'Folivari',
#     'origin_country': 'FR'},
#    {'id': 32853,
#     'logo_path': '/y1CUzdA8WOdKzikxTYL4xqCDlqF.png',
#     'name': 'GKIDS',
#     'origin_country': 'US'},
#    {'id': 277086,
#     'logo_path': None,
#     'name': 'Value & Power Culture Communications',
#     'origin_country': 'CN'},
#    {'id': 1898,
#     'logo_path': '/8ix6SGlJiyuUDxLBtY8E0PY2G7w.png',
#     'name': 'Fís Éireann/Screen Ireland',
#     'origin_country': 'IE'}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'IE', 'name': 'Ireland'},
#    {'iso_3166_1': 'LU', 'name': 'Luxembourg'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'CN', 'name': 'China'}],
#   'release_date': '2020-10-26',
#   'revenue': 1310720,
#   'runtime': 102,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Irish',
#     'iso_639_1': 'ga',
#     'name': 'Gaeilge'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Be fierce. Be wild. Be free.',
#   'title': 'Wolfwalkers',
#   'video': False,
#   'vote_average': 8.189,
#   'vote_count': 1364},
#  {'adult': False,
#   'backdrop_path': '/lMaWlYThCSnsmW3usxWTpSuyZp1.jpg',
#   'belongs_to_collection': None,
#   'budget': 49300000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://gkids.com/films/the-tale-of-the-princess-kaguya/',
#   'id': 149871,
#   'imdb_id': 'tt2576852',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'かぐや姫の物語',
#   'overview': 'Found inside a shining stalk of bamboo by an old bamboo cutter and his wife, a tiny girl grows rapidly into an exquisite young lady. The mysterious young princess enthrals all who encounter her. But, ultimately, she must confront her fate.',
#   'popularity': 4.762,
#   'poster_path': '/cQidJuA546OSSXKWXoiCeINDxuj.jpg',
#   'production_companies': [{'id': 10342,
#     'logo_path': '/uFuxPEZRUcBTEiYIxjHJq62Vr77.png',
#     'name': 'Studio Ghibli',
#     'origin_country': 'JP'},
#    {'id': 11846,
#     'logo_path': '/es3LvDA6wLWVDvZnAYYuAT6x8lJ.png',
#     'name': 'Hakuhodo DY Media Partners',
#     'origin_country': 'JP'},
#    {'id': 11848,
#     'logo_path': '/A3abKfh7dXwPdXJc3A551q8XnOC.png',
#     'name': 'KDDI',
#     'origin_country': 'JP'},
#    {'id': 20191,
#     'logo_path': None,
#     'name': 'Mitsubishi Shoji',
#     'origin_country': ''},
#    {'id': 6755,
#     'logo_path': '/bWiM2iY82B32NGmPCOFatgfekIR.png',
#     'name': 'Nippon Television Network Corporation',
#     'origin_country': 'JP'},
#    {'id': 882,
#     'logo_path': '/fRSWWjquvzcHjACbtF53utZFIll.png',
#     'name': 'TOHO',
#     'origin_country': 'JP'},
#    {'id': 28086,
#     'logo_path': None,
#     'name': 'T2 Studio',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2013-11-23',
#   'revenue': 24366656,
#   'runtime': 137,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': "A princess's crime and punishment.",
#   'title': 'The Tale of The Princess Kaguya',
#   'video': False,
#   'vote_average': 8.093,
#   'vote_count': 1967},
#  {'adult': False,
#   'backdrop_path': '/gl0jzn4BupSbL2qMVeqrjKkF9Js.jpg',
#   'belongs_to_collection': None,
#   'budget': 23500000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 16, 'name': 'Animation'}],
#   'homepage': 'http://www.princess-mononoke.com/',
#   'id': 128,
#   'imdb_id': 'tt0119698',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'もののけ姫',
#   'overview': 'Ashitaka, a prince of the disappearing Emishi people, is cursed by a demonized boar god and must journey to the west to find a cure. Along the way, he encounters San, a young human woman fighting to protect the forest, and Lady Eboshi, who is trying to destroy it. Ashitaka must find a way to bring balance to this conflict.',
#   'popularity': 15.1601,
#   'poster_path': '/cMYCDADoLKLbB83g4WnJegaZimC.jpg',
#   'production_companies': [{'id': 10342,
#     'logo_path': '/uFuxPEZRUcBTEiYIxjHJq62Vr77.png',
#     'name': 'Studio Ghibli',
#     'origin_country': 'JP'},
#    {'id': 1778,
#     'logo_path': '/b5rT6VbYza3LyfltCmz1OcqzWJM.png',
#     'name': 'dentsu',
#     'origin_country': 'JP'},
#    {'id': 1779,
#     'logo_path': '/41nGzTdCnORYZIZzaGZtfsBwQCl.png',
#     'name': 'Tokuma Shoten',
#     'origin_country': 'JP'},
#    {'id': 6755,
#     'logo_path': '/bWiM2iY82B32NGmPCOFatgfekIR.png',
#     'name': 'Nippon Television Network Corporation',
#     'origin_country': 'JP'},
#    {'id': 12516,
#     'logo_path': None,
#     'name': 'Nibariki',
#     'origin_country': 'JP'},
#    {'id': 67681, 'logo_path': None, 'name': 'TNDG', 'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '1997-07-12',
#   'revenue': 176506186,
#   'runtime': 134,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'The fate of the world rests on the courage of one warrior.',
#   'title': 'Princess Mononoke',
#   'video': False,
#   'vote_average': 8.323,
#   'vote_count': 8915},
#  {'adult': False,
#   'backdrop_path': '/8x9iKH8kWA0zdkgNdpAew7OstYe.jpg',
#   'belongs_to_collection': None,
#   'budget': 7500000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': 'https://www.funimationfilms.com/movie/yourname/',
#   'id': 372058,
#   'imdb_id': 'tt5311514',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '君の名は。',
#   'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#   'popularity': 25.7912,
#   'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#   'production_companies': [{'id': 3756,
#     'logo_path': '/t38uPdbKmyBB8brKKeTFWIwojRz.png',
#     'name': 'CoMix Wave Films',
#     'origin_country': 'JP'},
#    {'id': 882,
#     'logo_path': '/fRSWWjquvzcHjACbtF53utZFIll.png',
#     'name': 'TOHO',
#     'origin_country': 'JP'},
#    {'id': 2073,
#     'logo_path': '/tWxRSaKmRJNTcmtlXsmn5R4KOSU.png',
#     'name': 'KADOKAWA',
#     'origin_country': 'JP'},
#    {'id': 8157,
#     'logo_path': '/pEqcMX1aG3JvtDgfh2wNZJLCcb4.png',
#     'name': 'jeki',
#     'origin_country': 'JP'},
#    {'id': 14602,
#     'logo_path': '/t9eqx5QCHtu8LxxgYzivqrJAosp.png',
#     'name': 'AMUSE',
#     'origin_country': 'JP'},
#    {'id': 128617,
#     'logo_path': None,
#     'name': 'voque ting',
#     'origin_country': 'JP'},
#    {'id': 104184,
#     'logo_path': '/reEBh8dBl2y1DbXe2EdgxtMtaim.png',
#     'name': 'Lawson Entertainment',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2016-08-26',
#   'revenue': 405320132,
#   'runtime': 106,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Separated by distance, connected by fate.',
#   'title': 'Your Name.',
#   'video': False,
#   'vote_average': 8.476,
#   'vote_count': 12450},
#  {'adult': False,
#   'backdrop_path': '/6O1mOoTXuc1WqjKd2R7MFQHZ7Eb.jpg',
#   'belongs_to_collection': None,
#   'budget': 3700000,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://gkids.com/films/my-neighbor-totoro',
#   'id': 8392,
#   'imdb_id': 'tt0096283',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'となりのトトロ',
#   'overview': 'Two sisters move to the country with their father in order to be closer to their hospitalized mother, and discover the surrounding trees are inhabited by Totoros, magical spirits of the forest. When the youngest runs away from home, the older sister seeks help from the spirits to find her.',
#   'popularity': 12.6494,
#   'poster_path': '/rtGDOeG9LzoerkDGZF9dnVeLppL.jpg',
#   'production_companies': [{'id': 10342,
#     'logo_path': '/uFuxPEZRUcBTEiYIxjHJq62Vr77.png',
#     'name': 'Studio Ghibli',
#     'origin_country': 'JP'},
#    {'id': 12516,
#     'logo_path': None,
#     'name': 'Nibariki',
#     'origin_country': 'JP'},
#    {'id': 1779,
#     'logo_path': '/41nGzTdCnORYZIZzaGZtfsBwQCl.png',
#     'name': 'Tokuma Shoten',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '1988-04-16',
#   'revenue': 41000000,
#   'runtime': 86,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': "He's your friendly neighbourhood forest spirit!",
#   'title': 'My Neighbor Totoro',
#   'video': False,
#   'vote_average': 8.062,
#   'vote_count': 8750},
#  {'adult': False,
#   'backdrop_path': '/1EAxNqdkVnp48a7NUuNBHGflowM.jpg',
#   'belongs_to_collection': {'id': 210303,
#    'name': 'Rebuild of Evangelion Collection',
#    'poster_path': '/ma2MjOMz5V8c8D6kV3ReZbk7P3a.jpg',
#    'backdrop_path': '/las0P4Dua54XrZ73VQmGUaH1z0U.jpg'},
#   'budget': 29700000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': 'https://www.amazon.com/dp/B098WNZSQ3',
#   'id': 283566,
#   'imdb_id': 'tt2458948',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'シン・エヴァンゲリオン劇場版:||',
#   'overview': 'In the aftermath of the Fourth Impact, stranded without their Evangelions, Shinji, Asuka and Rei find refuge in one of the rare pockets of humanity that still exist on the ruined planet Earth. There, each lives a life far different from their days as an Evangelion pilot. However, the danger to the world is far from over. A new impact is looming on the horizon—one that will prove to be the true end of Evangelion.',
#   'popularity': 6.5954,
#   'poster_path': '/md5wZRRj8biHrGtyitgBZo7674t.jpg',
#   'production_companies': [{'id': 4145,
#     'logo_path': '/aEiJyMKr2CxrAJiIdtN70wXqn.png',
#     'name': 'khara',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2021-03-08',
#   'revenue': 93882453,
#   'runtime': 155,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Bye-bye, all of EVANGELION.',
#   'title': 'Evangelion: 3.0+1.0 Thrice Upon a Time',
#   'video': False,
#   'vote_average': 8.205,
#   'vote_count': 937},
#  {'adult': False,
#   'backdrop_path': '/5lAMQMWpXMsirvtLLvW7cJgEPkU.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'http://asilentvoice.com.au/',
#   'id': 378064,
#   'imdb_id': 'tt5323662',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '映画 聲の形',
#   'overview': 'Shouya Ishida starts bullying the new girl in class, Shouko Nishimiya, because she is deaf. But as the teasing continues, the rest of the class starts to turn on Shouya for his lack of compassion. When they leave elementary school, Shouko and Shouya do not speak to each other again... until an older, wiser Shouya, tormented by his past behaviour, decides he must see Shouko once more. He wants to atone for his sins, but is it already too late...?',
#   'popularity': 12.72,
#   'poster_path': '/tuFaWiqX0TXoWu7DGNcmX3UW7sT.jpg',
#   'production_companies': [{'id': 5438,
#     'logo_path': '/leZ8GPCL0GneHHayPVnXtB3p0We.png',
#     'name': 'Kyoto Animation',
#     'origin_country': 'JP'},
#    {'id': 86839,
#     'logo_path': '/cnOJAkVVmKZLIzmgw4fRRZ2dctT.png',
#     'name': 'ABC Animation',
#     'origin_country': 'JP'},
#    {'id': 59118,
#     'logo_path': '/9nTCEBgGaaI5swkv8gy2vny0Mb5.png',
#     'name': 'Kodansha',
#     'origin_country': 'JP'},
#    {'id': 9148,
#     'logo_path': '/rtW3NadfF4kR5mTW00ahiFxw6k7.png',
#     'name': 'Pony Canyon',
#     'origin_country': 'JP'},
#    {'id': 22715,
#     'logo_path': '/c4d6GLfUXbp44dbWWJqWCh7YrnO.png',
#     'name': 'Quaras',
#     'origin_country': 'JP'},
#    {'id': 192,
#     'logo_path': '/93eAKlnQecDdMtucfOprzcjMw9V.png',
#     'name': 'Shochiku',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2016-09-17',
#   'revenue': 30819442,
#   'runtime': 129,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Sometimes the answer is as simple as learning to listen.',
#   'title': 'A Silent Voice: The Movie',
#   'video': False,
#   'vote_average': 8.385,
#   'vote_count': 4446},
#  {'adult': False,
#   'backdrop_path': '/6GF9uJs7AnbcJvyfoZyjZv063Oo.jpg',
#   'belongs_to_collection': {'id': 94032,
#    'name': 'The Lion King Collection',
#    'poster_path': '/oG1heUs503GV6xBnFhgyYTGWm05.jpg',
#    'backdrop_path': '/A9IEaj9cPAwEgFnTmteB70oxgJY.jpg'},
#   'budget': 45000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': 'http://movies.disney.com/the-lion-king',
#   'id': 8587,
#   'imdb_id': 'tt0110357',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Lion King',
#   'overview': 'Young lion prince Simba, eager to one day become king of the Pride Lands, grows up under the watchful eye of his father Mufasa; all the while his villainous uncle Scar conspires to take the throne for himself. Amid betrayal and tragedy, Simba must confront his past and find his rightful place in the Circle of Life.',
#   'popularity': 25.0943,
#   'poster_path': '/sKCr78MXSLixwmZ8DyJLrpMsd15.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 171656,
#     'logo_path': '/4UBohOtIr9DtxylH48Qsg6aDow6.png',
#     'name': 'Walt Disney Feature Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1994-06-15',
#   'revenue': 763455561,
#   'runtime': 89,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The greatest adventure of all is finding our place in the Circle of Life.',
#   'title': 'The Lion King',
#   'video': False,
#   'vote_average': 8.253,
#   'vote_count': 19592},
#  {'adult': False,
#   'backdrop_path': '/kY0t0sezPpMK78TERPuSkAsFM2E.jpg',
#   'belongs_to_collection': {'id': 525179,
#    'name': "It's Such a Beautiful Day Collection",
#    'poster_path': '/aBigetUJUIv0XMSiw4dO3gG3rqQ.jpg',
#    'backdrop_path': '/tbxRYmpukc23yjfB3hUrgmf91o2.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'https://vimeo.com/ondemand/itssuchabeautifulday',
#   'id': 86517,
#   'imdb_id': 'tt2078648',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': "It's Such a Beautiful Day",
#   'overview': 'Dark and troubling events force Bill to reckon with the meaning of his life.',
#   'popularity': 0.2534,
#   'poster_path': '/gZIBj1iJAbz5d0pi01FZ4HJLAAq.jpg',
#   'production_companies': [{'id': 63349,
#     'logo_path': '/dcUSkPxHyTlAQey6ioH4ZmUMKKA.png',
#     'name': 'Bitter Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2011-11-17',
#   'revenue': 0,
#   'runtime': 23,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': "It's Such a Beautiful Day",
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 120},
#  {'adult': False,
#   'backdrop_path': '/1Q5b34cge5nClCpamxf3HkU18W1.jpg',
#   'belongs_to_collection': None,
#   'budget': 315000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'https://www.warnerbros.com/movies/how-grinch-stole-christmas',
#   'id': 13377,
#   'imdb_id': 'tt0060345',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'How the Grinch Stole Christmas!',
#   'overview': 'Bitter and hateful, the Grinch is irritated at the thought of a nearby village having a happy time celebrating Christmas. Disguised as Santa Claus, with his dog made to look like a reindeer, he decides to raid the village to steal all the Christmas things.',
#   'popularity': 2.5839,
#   'poster_path': '/7ir0iRuPK9OEuH569cp0nF5CJce.jpg',
#   'production_companies': [{'id': 8811,
#     'logo_path': None,
#     'name': 'The Cat in the Hat Productions',
#     'origin_country': 'US'},
#    {'id': 54210,
#     'logo_path': None,
#     'name': 'MGM Animation/Visual Arts',
#     'origin_country': 'US'},
#    {'id': 2230,
#     'logo_path': '/igOjospzsKQIbpuFCGhoN5F9icS.png',
#     'name': 'MGM Television',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1966-12-18',
#   'revenue': 0,
#   'runtime': 25,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "You're a mean one, Mr. Grinch",
#   'title': 'How the Grinch Stole Christmas!',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 1130},
#  {'adult': False,
#   'backdrop_path': '/uyvKj5YrunaVbl2Z9kNBA9wIi8D.jpg',
#   'belongs_to_collection': {'id': 506918,
#    'name': 'World of Tomorrow Collection',
#    'poster_path': '/2KiI14ZZzE7W9E93sldyNBmKrYj.jpg',
#    'backdrop_path': '/lxjvh7coxKZyzxxBbUO70u5To7r.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://bitterfilms.com',
#   'id': 303867,
#   'imdb_id': 'tt4171032',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'World of Tomorrow',
#   'overview': 'A little girl is taken on a mind-bending tour of her distant future.',
#   'popularity': 0.6866,
#   'poster_path': '/5s7DSOek7Bk2CvcG1zX01bJzJ0x.jpg',
#   'production_companies': [{'id': 63349,
#     'logo_path': '/dcUSkPxHyTlAQey6ioH4ZmUMKKA.png',
#     'name': 'Bitter Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-01-22',
#   'revenue': 0,
#   'runtime': 17,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'World of Tomorrow',
#   'video': False,
#   'vote_average': 7.818,
#   'vote_count': 359},
#  {'adult': False,
#   'backdrop_path': '/1u03hsF4PIT5HcM1b5oyRQvYjeV.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 99, 'name': 'Documentary'}],
#   'homepage': 'http://www.towerdocumentary.com',
#   'id': 381028,
#   'imdb_id': 'tt5116410',
#   'origin_country': [],
#   'original_language': 'en',
#   'original_title': 'Tower',
#   'overview': 'Combining archival footage with rotoscopic animation, Tower reveals the action-packed untold stories of the witnesses, heroes and survivors of America’s first mass school shooting, when the worst in one man brought out the best in so many others.',
#   'popularity': 0.7117,
#   'poster_path': '/sYau8BFtkQUMWDyRbpACru4cS6G.jpg',
#   'production_companies': [{'id': 85095,
#     'logo_path': None,
#     'name': 'Independent Lens',
#     'origin_country': 'US'},
#    {'id': 79140,
#     'logo_path': None,
#     'name': 'Go-Valley',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2016-03-13',
#   'revenue': 101987,
#   'runtime': 82,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'August 1, 1966, was the day our innocence was shattered.',
#   'title': 'Tower',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 200},
#  {'adult': False,
#   'backdrop_path': '/wfClZdRb1x4LZ8B73Y9RSn8XAPa.jpg',
#   'belongs_to_collection': None,
#   'budget': 50000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.warnerbros.com/iron-giant',
#   'id': 10386,
#   'imdb_id': 'tt0129167',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Iron Giant',
#   'overview': 'In the small town of Rockwell, Maine in October 1957, a giant metal machine befriends a nine-year-old boy and ultimately finds its humanity by unselfishly saving people from their own fears and prejudices.',
#   'popularity': 7.6536,
#   'poster_path': '/ct04FCFLPImNG5thcPLRnVsZlmS.jpg',
#   'production_companies': [{'id': 215559,
#     'logo_path': '/4uvuj56cK745ebWYnaC93hOX9DO.png',
#     'name': 'Warner Bros. Feature Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1999-08-06',
#   'revenue': 23300000,
#   'runtime': 86,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'It came from outer space!',
#   'title': 'The Iron Giant',
#   'video': False,
#   'vote_average': 7.952,
#   'vote_count': 6116},
#  {'adult': False,
#   'backdrop_path': '/rA9QYI7yTV2F2AvaqBcq1vL3MOr.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 489412,
#   'imdb_id': 'tt2396224',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': "It's Such a Beautiful Day",
#   'overview': 'Bill struggles to put together his shattered psyche.',
#   'popularity': 1.2652,
#   'poster_path': '/hop0dsM4nxyNENGhBhpJWTCJ5rS.jpg',
#   'production_companies': [{'id': 63349,
#     'logo_path': '/dcUSkPxHyTlAQey6ioH4ZmUMKKA.png',
#     'name': 'Bitter Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2012-08-24',
#   'revenue': 0,
#   'runtime': 62,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': "It's Such a Beautiful Day",
#   'video': False,
#   'vote_average': 7.917,
#   'vote_count': 367},
#  {'adult': False,
#   'backdrop_path': '/521koHpCyK6ZeNpEAvPAuC75cJ5.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 652837,
#   'imdb_id': 'tt12879624',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'ジョゼと虎と魚たち',
#   'overview': 'With dreams of diving abroad, Tsuneo gets a job assisting Josee, an artist whose imagination takes her far beyond her wheelchair. But when the tide turns against them, they push each other to places they never thought possible, and inspire a love fit for a storybook.',
#   'popularity': 7.5672,
#   'poster_path': '/z1D8xi9x4uEhyFruo7uEHXUMD4K.jpg',
#   'production_companies': [{'id': 2849,
#     'logo_path': '/cN3JNIKawjOMtfk0GBVIbsx69bg.png',
#     'name': 'BONES',
#     'origin_country': 'JP'},
#    {'id': 2073,
#     'logo_path': '/tWxRSaKmRJNTcmtlXsmn5R4KOSU.png',
#     'name': 'KADOKAWA',
#     'origin_country': 'JP'},
#    {'id': 192,
#     'logo_path': '/93eAKlnQecDdMtucfOprzcjMw9V.png',
#     'name': 'Shochiku',
#     'origin_country': 'JP'},
#    {'id': 8157,
#     'logo_path': '/pEqcMX1aG3JvtDgfh2wNZJLCcb4.png',
#     'name': 'jeki',
#     'origin_country': 'JP'},
#    {'id': 139842,
#     'logo_path': '/uBixtDwl2hxsugqSOTzEP90kxa0.png',
#     'name': "TOY'S FACTORY",
#     'origin_country': 'JP'},
#    {'id': 11848,
#     'logo_path': '/A3abKfh7dXwPdXJc3A551q8XnOC.png',
#     'name': 'KDDI',
#     'origin_country': 'JP'},
#    {'id': 170125,
#     'logo_path': '/aQ07cYAVuJCmfuCeiaDnmmhdibk.png',
#     'name': 'Movie Walker',
#     'origin_country': 'JP'},
#    {'id': 91253,
#     'logo_path': '/aD91ywW7l93wk9N0fNX8URMgQSC.png',
#     'name': 'TBS Radio',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2020-12-25',
#   'revenue': 0,
#   'runtime': 98,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Together they can fly.',
#   'title': 'Josee, the Tiger and the Fish',
#   'video': False,
#   'vote_average': 8.255,
#   'vote_count': 588},
#  {'adult': False,
#   'backdrop_path': '/jFEy7DClkMm8nGXAwmpe577Vlq0.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 16, 'name': 'Animation'}],
#   'homepage': 'http://www.warnerbros.com/batman-under-red-hood',
#   'id': 40662,
#   'imdb_id': 'tt1569923',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Batman: Under the Red Hood',
#   'overview': 'One part vigilante, one part criminal kingpin, Red Hood begins cleaning up Gotham with the efficiency of Batman, but without following the same ethical code.',
#   'popularity': 3.2227,
#   'poster_path': '/7lmHqHg1rG9b4U8MjuyQjmJ7Qm0.jpg',
#   'production_companies': [{'id': 2785,
#     'logo_path': '/l5zW8jjmQOCx2dFmvnmbYmqoBmL.png',
#     'name': 'Warner Bros. Animation',
#     'origin_country': 'US'},
#    {'id': 429,
#     'logo_path': '/4Y00XuSMuP1gimd0jP6JT57QbCI.png',
#     'name': 'DC',
#     'origin_country': 'US'},
#    {'id': 4811,
#     'logo_path': '/7xym5CnL4LcMPaWpp51cN1v73AR.png',
#     'name': 'Warner Premiere',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2010-07-27',
#   'revenue': 6629178,
#   'runtime': 75,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Dare to look beneath the Hood.',
#   'title': 'Batman: Under the Red Hood',
#   'video': False,
#   'vote_average': 7.759,
#   'vote_count': 1715},
#  {'adult': False,
#   'backdrop_path': '/YLyORLsYIjC0d1TFBSpJKk7piP.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'https://kimisui-anime.com/',
#   'id': 504253,
#   'imdb_id': 'tt7236034',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '君の膵臓をたべたい',
#   'overview': 'After his classmate and crush is diagnosed with a pancreatic disease, an average high schooler sets out to make the most of her final days.',
#   'popularity': 6.8656,
#   'poster_path': '/qpV8kvRfAntV7D4aOOsLIz7OdPc.jpg',
#   'production_companies': [{'id': 86839,
#     'logo_path': '/cnOJAkVVmKZLIzmgw4fRRZ2dctT.png',
#     'name': 'ABC Animation',
#     'origin_country': 'JP'},
#    {'id': 2883,
#     'logo_path': '/rDYExnBV61jGQnkhVVrPN4Yl7O1.png',
#     'name': 'Aniplex',
#     'origin_country': 'JP'},
#    {'id': 8157,
#     'logo_path': '/pEqcMX1aG3JvtDgfh2wNZJLCcb4.png',
#     'name': 'jeki',
#     'origin_country': 'JP'},
#    {'id': 62866,
#     'logo_path': '/uYawQ0Lb8smRXNNCoq8gTHG92Pz.png',
#     'name': 'Futabasha',
#     'origin_country': 'JP'},
#    {'id': 56933,
#     'logo_path': '/ogbbk2xvszgQwkf4msNbH5lhsM9.png',
#     'name': 'Studio VOLN',
#     'origin_country': 'JP'},
#    {'id': 145105,
#     'logo_path': '/oFUDvCLCRmAXlGqjmwO8CN33ygl.png',
#     'name': 'Tohan',
#     'origin_country': 'JP'},
#    {'id': 3031,
#     'logo_path': '/2JcgVKZ1gEY5RsLJU1CGj1MaKFj.png',
#     'name': 'The Asahi Shimbun',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2018-09-01',
#   'revenue': 33748006,
#   'runtime': 108,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'This is a story about an unforgettable spring...',
#   'title': 'I Want to Eat Your Pancreas',
#   'video': False,
#   'vote_average': 8.223,
#   'vote_count': 1761},
#  {'adult': False,
#   'backdrop_path': '/pSL75Sg1APD4OHpQs4VyFb8pIFv.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': '',
#   'id': 22504,
#   'imdb_id': 'tt0079820',
#   'origin_country': ['FR'],
#   'original_language': 'fr',
#   'original_title': "Le Roi et l'Oiseau",
#   'overview': "A young shepherdess and a chimneysweep plan to get married and escape the clutches of a tyrannical king in love with her, assisted by the guile of a cheeky mockingbird, the king's archenemy.",
#   'popularity': 0.7281,
#   'poster_path': '/yDbfVUrb9b0Dkm1TptWtzkujXBk.jpg',
#   'production_companies': [{'id': 30098,
#     'logo_path': None,
#     'name': 'Les Films Paul Grimault',
#     'origin_country': 'FR'},
#    {'id': 22358,
#     'logo_path': None,
#     'name': 'Les Films Gibé',
#     'origin_country': 'FR'},
#    {'id': 1117,
#     'logo_path': '/2X2uFeObxawiAajNDOf3Mhri5Wg.png',
#     'name': 'Antenne 2',
#     'origin_country': 'FR'}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '1980-03-19',
#   'revenue': 0,
#   'runtime': 83,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'French',
#     'iso_639_1': 'fr',
#     'name': 'Français'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The King and the Mockingbird',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 408},
#  {'adult': False,
#   'backdrop_path': '/yDyC5l7vyLx2ZzXqZMoqOPGKttl.jpg',
# ...
#     'logo_path': '/fK2QKfHdSdw42Xx4MiD7KhDufBV.png',
#     'name': 'Shin-Ei Animation',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2006-04-15',
#   'revenue': 0,
#   'runtime': 91,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Crayon Shin-chan: The Legend Called Dance! Amigo!',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 39},
#  {'adult': False,
#   'backdrop_path': '/iGu27QGQtquhweyxXoVK4N6FkHs.jpg',
#   'belongs_to_collection': {'id': 117354,
#    'name': 'Crayon Shin-chan Collection',
#    'poster_path': '/l0xXzzMz0xzR1J9nwB5fVz3ywNZ.jpg',
#    'backdrop_path': '/2IxX864lSyaC3Yn748Bw3ulhoeT.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 128868,
#   'imdb_id': 'tt0409848',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'クレヨンしんちゃん アクション仮面VSハイグレ魔王',
#   'overview': "Everyone's favorite TV superhero Action Mask shows up in Kasukabe, and he's trying to get something from Shin-chan -- but what could it be?",
#   'popularity': 2.3653,
#   'poster_path': '/9GzmjFn1iosYdKn7DPnClK8ezrE.jpg',
#   'production_companies': [{'id': 9300,
#     'logo_path': '/9sSD1XufVCJWAadNiC9Mwu994VD.png',
#     'name': 'TV Asahi',
#     'origin_country': 'JP'},
#    {'id': 5141,
#     'logo_path': '/fK2QKfHdSdw42Xx4MiD7KhDufBV.png',
#     'name': 'Shin-Ei Animation',
#     'origin_country': 'JP'},
#    {'id': 4720,
#     'logo_path': '/7wQgZTA4FCkFMDedBYVZiVE87c7.png',
#     'name': 'ADK',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '1993-07-24',
#   'revenue': 0,
#   'runtime': 93,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Crayon Shin-chan: Action Mask vs. Leotard Devil',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 60},
#  {'adult': False,
#   'backdrop_path': '/z3gjCf4uwToqd1tkDyqtZ6zTcQe.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'http://girls-und-panzer.jp/',
#   'id': 357405,
#   'imdb_id': 'tt5284414',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'ガールズ&パンツァー 劇場版',
#   'overview': 'When the Ministry of Education goes back on its promise to keep Ooarai Girls Academy open, the task of saving the five-mile-long Academy Ship from the wreckers falls to Miho and her barely-seasoned tankery team. However, things go off track almost immediately. While the Oorai tank crew may have won the high school tournament, they’re now facing a larger and more experienced university team, and if they fail, their armored vehicles will be forfeit! Will they be swapping their tanks for the memories? It’s possible, but winning a tank battle is all about tactics and teamwork, and the fledgling Ooarai students have more friends and allies than anyone suspects.',
#   'popularity': 3.0209,
#   'poster_path': '/jGa3LLsUzj9gooXstNyTIqazOWS.jpg',
#   'production_companies': [{'id': 30125,
#     'logo_path': '/idI9yjIWXWgLLdWqUbBpWzmTW9t.png',
#     'name': 'Actas',
#     'origin_country': 'JP'},
#    {'id': 6683,
#     'logo_path': '/reCkuk3GEomdx5gQpsm15Zl1sgX.png',
#     'name': 'Lantis',
#     'origin_country': 'JP'},
#    {'id': 528,
#     'logo_path': '/fO3Aof3lXQclYpBByYC8aneTXwA.png',
#     'name': 'Bandai Visual',
#     'origin_country': 'JP'},
#    {'id': 11846,
#     'logo_path': '/es3LvDA6wLWVDvZnAYYuAT6x8lJ.png',
#     'name': 'Hakuhodo DY Media Partners',
#     'origin_country': 'JP'},
#    {'id': 142186,
#     'logo_path': '/bdXTOuU7PdsDtQngyM7vb47zePs.png',
#     'name': 'Hakuhodo DY Music & Pictures',
#     'origin_country': 'JP'},
#    {'id': 3466,
#     'logo_path': '/lmCg0zarmM52wrmsZRUY0QlPKLh.png',
#     'name': 'movic',
#     'origin_country': 'JP'},
#    {'id': 12541, 'logo_path': None, 'name': 'Q-TEC', 'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2015-11-21',
#   'revenue': 0,
#   'runtime': 120,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Panzer Vor!',
#   'title': 'Girls und Panzer der Film',
#   'video': False,
#   'vote_average': 6.973,
#   'vote_count': 55},
#  {'adult': False,
#   'backdrop_path': '/kBgDeXKBBrVdbkm0ItJA2Z0avlF.jpg',
#   'belongs_to_collection': {'id': 19163,
#    'name': 'The Land Before Time Collection',
#    'poster_path': '/n1bjdBVThBezxR6nEf2dy43sTtV.jpg',
#    'backdrop_path': '/zDkQ0BPPhsmepLGZJx0aXVAuKG6.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 31933,
#   'imdb_id': 'tt0933064',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Land Before Time XII: The Great Day of the Flyers',
#   'overview': "As the Great Day of the Flyers nears, the Great Valley's flying youngsters are eager to participate in the annual exhibition to show off their skills. Everyone, that is, except free-spirited pterodactyl Petrie, whose individualism causes problems when it comes to staying in formation. Enter his dinosaur pals Littlefoot, Cera, Spike and Ducky, who encourage Petrie to embrace his uniqueness.",
#   'popularity': 1.5241,
#   'poster_path': '/7WKZksck9oLWBQnSZYdmrhaY3At.jpg',
#   'production_companies': [{'id': 5556,
#     'logo_path': '/qtdp2UWJNleyYy6ur7DDgPYUxqz.png',
#     'name': 'Universal Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2006-02-27',
#   'revenue': 0,
#   'runtime': 77,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Land Before Time XII: The Great Day of the Flyers',
#   'video': False,
#   'vote_average': 6.2,
#   'vote_count': 180},
#  {'adult': False,
#   'backdrop_path': '/72Pgfgg9zKI2MjY57AObWeeZS0V.jpg',
#   'belongs_to_collection': {'id': 212160,
#    'name': 'Code Geass: Akito the Exiled Collection',
#    'poster_path': '/sF82ivr9yYpw69JbCnuWonR107p.jpg',
#    'backdrop_path': '/iTxASLlhUsZ1MwOvt89VlM7l2ut.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10752, 'name': 'War'}],
#   'homepage': '',
#   'id': 185526,
#   'imdb_id': 'tt3354096',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'コードギアス 亡国のアキト 第1章「翼竜は舞い降りた」',
#   'overview': 'The side story takes place in 2017 a.t.b., between the rise of the “Black Knights” organization and the return of the supposedly "dead" Zero. The setting is in Europe, where the European Union (E.U.) allied nations are being invaded by the overwhelming forces of the Holy Britannian Empire. On the verge of defeat, the E.U. army forms a special unit known as “W-0″, of which a young pilot named Akito Hyuga is a member. Leila Malkal , a former Britannian Aristocrat comes to the E.U.\'s aid, commanding the “Wyvern” Knightmare corps comprised of Japanese teenagers. They recklessly plunge into a battlefield, where the survival rate is extremely low, at about 5% only. They fight for their freedom and for a "home" to which they can return.',
#   'popularity': 2.5941,
#   'poster_path': '/6fytnsNxIF4kBdRbzHQzMNLaAnT.jpg',
#   'production_companies': [{'id': 3153,
#     'logo_path': '/yKZ9UarLSu9Y4Gpw33nKRQOPM7z.png',
#     'name': 'SUNRISE',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2012-08-04',
#   'revenue': 447630,
#   'runtime': 51,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Code Geass: Akito the Exiled 1: The Wyvern Arrives',
#   'video': False,
#   'vote_average': 6.231,
#   'vote_count': 78},
#  {'adult': False,
#   'backdrop_path': '/9AJNEWmprXEIRhMdWFirYn1egbZ.jpg',
#   'belongs_to_collection': None,
#   'budget': 28000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 54648,
#   'imdb_id': 'tt0114108',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Pebble and the Penguin',
#   'overview': "A bashful bachelor penguin named Hubie, who's partial to a pretty female named Marina. Ancient penguin ritual dictates that males present a pebble to their intended, then mate for life. Hubie finds a spiffy stone, but before he can bestow it on Marina, dastardly rival Drake tosses him into the churning sea, and Hubie gets swept away.",
#   'popularity': 1.4106,
#   'poster_path': '/aWi36nNbyMw51yGN0tTSOrOLu6L.jpg',
#   'production_companies': [{'id': 6422,
#     'logo_path': '/rxO73jR41tGlohvPGMC3sJeclcf.png',
#     'name': 'Don Bluth Entertainment',
#     'origin_country': 'US'},
#    {'id': 211615,
#     'logo_path': '/rxO73jR41tGlohvPGMC3sJeclcf.png',
#     'name': 'Don Bluth Ireland',
#     'origin_country': 'IE'},
#    {'id': 21,
#     'logo_path': '/usUnaYV6hQnlVAXP6r4HwrlLFPG.png',
#     'name': 'Metro-Goldwyn-Mayer',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'},
#    {'iso_3166_1': 'IE', 'name': 'Ireland'}],
#   'release_date': '1995-04-12',
#   'revenue': 3983912,
#   'runtime': 74,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The adventure of a lifetime begins with one small pebble.',
#   'title': 'The Pebble and the Penguin',
#   'video': False,
#   'vote_average': 5.212,
#   'vote_count': 132},
#  {'adult': False,
#   'backdrop_path': '/ue9NbWclKr7r3EuT0xSGKSSJ7R0.jpg',
#   'belongs_to_collection': {'id': 144200,
#    'name': 'The Swan Princess Collection',
#    'poster_path': '/gTDPdkPuJjAKLL8pjXfXR0zVBDs.jpg',
#    'backdrop_path': '/jImeIPolLKUm1wiVTWL5nFvaKJH.jpg'},
#   'budget': 0,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 54113,
#   'imdb_id': 'tt0120254',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Swan Princess: Escape from Castle Mountain',
#   'overview': 'The first wedding anniversary of Princess Odette and Prince Derek is fraught with troubles brought on by Clavius, who plots to conquer the world.',
#   'popularity': 1.5142,
#   'poster_path': '/baMeQSxukVdPVQUSGhtKe6fA4aR.jpg',
#   'production_companies': [{'id': 4108,
#     'logo_path': None,
#     'name': 'Rich Animation Studios',
#     'origin_country': ''},
#    {'id': 105398,
#     'logo_path': None,
#     'name': 'Swan II LLC',
#     'origin_country': ''},
#    {'id': 4107,
#     'logo_path': '/nV1eu9bqF38PufXbth8BrVltXWR.png',
#     'name': 'NEST Family Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1997-06-19',
#   'revenue': 273644,
#   'runtime': 71,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Croatian',
#     'iso_639_1': 'hr',
#     'name': 'Hrvatski'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'It Will Take All Her Magic to Rescue Her Friends!',
#   'title': 'The Swan Princess: Escape from Castle Mountain',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 289},
#  {'adult': False,
#   'backdrop_path': '/9AFWONBBVKyDiUtD89kXNnKnG4b.jpg',
#   'belongs_to_collection': {'id': 661028,
#    'name': 'Pokémon: Best Wishes! Collection',
#    'poster_path': '/eS5KNWUMNats5QfPkSMyk4qJxxP.jpg',
#    'backdrop_path': '/rrDc86vxYrKhIDAA6MdD1u6Woig.jpg'},
#   'budget': 0,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.pokemon.com/us/pokemon-episodes/pokemon-movies/pokemon-the-movie-kyurem-vs-the-sword-of-justice-2012',
#   'id': 150213,
#   'imdb_id': 'tt2549540',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': '劇場版ポケットモンスター ベストウイッシュ キュレムVS聖剣士 ケルディオ',
#   'overview': 'Ash and his two friends Iris and Cilan help a Keldeo battle against a powerful Dragon-type Pokémon named Kyurem its his test to become a Sacred Swordsman.',
#   'popularity': 2.9159,
#   'poster_path': '/7gQEAR8aaCQRtJi7wq26ST5hukn.jpg',
#   'production_companies': [{'id': 8157,
#     'logo_path': '/pEqcMX1aG3JvtDgfh2wNZJLCcb4.png',
#     'name': 'jeki',
#     'origin_country': 'JP'},
#    {'id': 5372,
#     'logo_path': '/tPtJc2rCOTHEzJQPStT6m3dI0eK.png',
#     'name': 'OLM',
#     'origin_country': 'JP'},
#    {'id': 12653,
#     'logo_path': None,
#     'name': 'Pikachu Project',
#     'origin_country': 'JP'},
#    {'id': 12655,
#     'logo_path': '/dfGqf2NoMVPrDywDL90D5HAhBlW.png',
#     'name': 'Shogakukan-Shueisha Productions',
#     'origin_country': 'JP'},
#    {'id': 3034,
#     'logo_path': '/jnuO8pZNEBLEq5YaOP1f5OkmG91.png',
#     'name': 'TV Tokyo',
#     'origin_country': 'JP'},
#    {'id': 12654,
#     'logo_path': '/hBWpNb7x4R77xxltwNtM0ANboW6.png',
#     'name': 'The Pokémon Company',
#     'origin_country': 'JP'},
#    {'id': 13070,
#     'logo_path': '/ks2FscpAGYlfj4ZawdQF5vgtWyM.png',
#     'name': 'TakaraTomy',
#     'origin_country': 'JP'},
#    {'id': 9149,
#     'logo_path': '/isLUpud9N56ifftJZ4XvzwBBpoG.png',
#     'name': 'Shogakukan',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2012-07-13',
#   'revenue': 44057737,
#   'runtime': 72,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Pokémon the Movie: Kyurem vs. the Sword of Justice',
#   'video': False,
#   'vote_average': 6.361,
#   'vote_count': 183},
#  {'adult': False,
#   'backdrop_path': '/qfTGzbtqTBhz1krD0Zh5bCg5xlf.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'http://www.bayonetta-movie.com/',
#   'id': 242546,
#   'imdb_id': 'tt3306776',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'ベヨネッタ ブラッディフェイト',
#   'overview': 'Bayonetta is an ancient witch who awakens from a five hundred-year slumber with no memory of her life. Armed with a gun in each limb, she embarks on a journey to rediscover her past, defeating all bloodthirsty angels that stand in her way.',
#   'popularity': 2.0651,
#   'poster_path': '/dfg7dqm0YX16D6QYDKDdh3Qi930.jpg',
#   'production_companies': [{'id': 1077,
#     'logo_path': '/1tpNgC6BptieT9oF2LJ7H6pbG6S.png',
#     'name': 'GONZO',
#     'origin_country': 'JP'},
#    {'id': 35971,
#     'logo_path': '/5q5P83YiDQa34FgGd2Wtw7aWBnr.png',
#     'name': 'Graphinica',
#     'origin_country': 'JP'},
#    {'id': 2788,
#     'logo_path': '/16p9VkS5ddLMqb4JNMJ4f9omTKx.png',
#     'name': 'Avex Entertainment',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2013-11-23',
#   'revenue': 0,
#   'runtime': 91,
#   'softcore': False,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Bayonetta: Bloody Fate',
#   'video': False,
#   'vote_average': 6.851,
#   'vote_count': 121},
#  ...]

# %%
tmdb_3d = []

# %%
for i, row in movies_3d_df.iterrows():
    try:
        tmdb_3d.append(tmdb.Movies(row['tmdb']).info())
    except:
        continue

# %%
tmdb_movies_2d = pd.DataFrame(tmdb_2d)

# %%
tmdb_movies_2d = tmdb_movies_2d[['title', 'id', 'genres', 'overview', 'release_date', 'runtime', 'budget', 'revenue', 'origin_country', 'original_language', 'spoken_languages', 'production_companies', 'production_countries', 'vote_average', 'vote_count', 'popularity']]

# %%
tmdb_movies_2d['genres'][0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'}]

# %%
str([g['name'] for g in tmdb_movies_2d['genres'][0]])[1:-1].replace('\'', '').replace(',', ';')
# Out:
# 'Animation; Family; Fantasy'

# %%
for i, row in tmdb_movies_2d.iterrows():
    tmdb_movies_2d.loc[i, 'genres_list'] = str([g['name'] for g in row['genres']])[1:-1].replace('\'', '')

# %%
tmdb_movies_2d.head()
# Out:
#                               title       id  \
# 0                     Spirited Away      129
# 1  Attack on Titan: THE LAST ATTACK  1333100
# 2            Grave of the Fireflies    12477
# 3      Violet Evergarden: The Movie   533514
# 4                         Look Back  1244492
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
#
#                                             overview release_date  runtime  \
# 0  A young girl, Chihiro, becomes trapped in a st...   2001-07-20      125
# 1  A colossal-sized omnibus film bringing togethe...   2024-03-20      145
# 2  In the final months of World War II, 14-year-o...   1988-04-16       89
# 3  As the world moves on from the war and technol...   2020-09-18      140
# 4  Popular, outgoing Fujino is celebrated by her ...   2024-06-28       58
#
#      budget    revenue origin_country original_language  \
# 0  19000000  274925095           [JP]                ja
# 1         0   21525687           [JP]                ja
# 2   3700000     842132           [JP]                ja
# 3         0   20339624           [JP]                ja
# 4         0   12648664           [JP]                ja
#
#                                     spoken_languages  \
# 0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 1  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 2  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 3  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 4  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
#
#                                 production_companies  \
# 0  [{'id': 10342, 'logo_path': '/uFuxPEZRUcBTEiYI...
# 1  [{'id': 21444, 'logo_path': '/wSejGn3lAZdQ5muB...
# 2  [{'id': 10342, 'logo_path': '/uFuxPEZRUcBTEiYI...
# 3  [{'id': 5438, 'logo_path': '/leZ8GPCL0GneHHayP...
# 4  [{'id': 136998, 'logo_path': '/4Gw6jh3aUoJArME...
#
#                       production_countries  vote_average  vote_count  \
# 0  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.500       18194
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.736         184
# 2  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.400        6473
# 3  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.287         501
# 4  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.000         525
#
#    popularity                          genres_list
# 0     35.0613           Animation, Family, Fantasy
# 1      6.8777  Animation, Action, Adventure, Drama
# 2      0.0148                Animation, Drama, War
# 3      7.8410   Animation, Drama, Fantasy, Romance
# 4      9.6644                     Animation, Drama

# %%
tmdb_movies_2d['production_companies'][0]
# Out:
# [{'id': 10342,
#   'logo_path': '/uFuxPEZRUcBTEiYIxjHJq62Vr77.png',
#   'name': 'Studio Ghibli',
#   'origin_country': 'JP'},
#  {'id': 1779,
#   'logo_path': '/41nGzTdCnORYZIZzaGZtfsBwQCl.png',
#   'name': 'Tokuma Shoten',
#   'origin_country': 'JP'},
#  {'id': 6755,
#   'logo_path': '/bWiM2iY82B32NGmPCOFatgfekIR.png',
#   'name': 'Nippon Television Network Corporation',
#   'origin_country': 'JP'},
#  {'id': 11847,
#   'logo_path': '/rZP0I1p3hZNUMNFPHUSal6rWThQ.png',
#   'name': 'Mitsubishi',
#   'origin_country': 'JP'},
#  {'id': 1778,
#   'logo_path': '/b5rT6VbYza3LyfltCmz1OcqzWJM.png',
#   'name': 'dentsu',
#   'origin_country': 'JP'},
#  {'id': 1780,
#   'logo_path': '/4Qzhr7FxVtaMwmsh7118G3yvOhO.png',
#   'name': 'TFC',
#   'origin_country': 'JP'}]

# %%
for i, row in tmdb_movies_2d.iterrows():
    tmdb_movies_2d.loc[i, 'production_companies_list'] = str([g['name'] for g in row['production_companies']])[1:-1]

# %%
tmdb_movies_2d.head()
# Out:
#                               title       id  \
# 0                     Spirited Away      129
# 1  Attack on Titan: THE LAST ATTACK  1333100
# 2            Grave of the Fireflies    12477
# 3      Violet Evergarden: The Movie   533514
# 4                         Look Back  1244492
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
#
#                                             overview release_date  runtime  \
# 0  A young girl, Chihiro, becomes trapped in a st...   2001-07-20      125
# 1  A colossal-sized omnibus film bringing togethe...   2024-03-20      145
# 2  In the final months of World War II, 14-year-o...   1988-04-16       89
# 3  As the world moves on from the war and technol...   2020-09-18      140
# 4  Popular, outgoing Fujino is celebrated by her ...   2024-06-28       58
#
#      budget    revenue origin_country original_language  \
# 0  19000000  274925095           [JP]                ja
# 1         0   21525687           [JP]                ja
# 2   3700000     842132           [JP]                ja
# 3         0   20339624           [JP]                ja
# 4         0   12648664           [JP]                ja
#
#                                     spoken_languages  \
# 0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 1  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 2  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 3  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 4  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
#
#                                 production_companies  \
# 0  [{'id': 10342, 'logo_path': '/uFuxPEZRUcBTEiYI...
# 1  [{'id': 21444, 'logo_path': '/wSejGn3lAZdQ5muB...
# 2  [{'id': 10342, 'logo_path': '/uFuxPEZRUcBTEiYI...
# 3  [{'id': 5438, 'logo_path': '/leZ8GPCL0GneHHayP...
# 4  [{'id': 136998, 'logo_path': '/4Gw6jh3aUoJArME...
#
#                       production_countries  vote_average  vote_count  \
# 0  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.500       18194
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.736         184
# 2  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.400        6473
# 3  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.287         501
# 4  [{'iso_3166_1': 'JP', 'name': 'Japan'}]         8.000         525
#
#    popularity                          genres_list  \
# 0     35.0613           Animation, Family, Fantasy
# 1      6.8777  Animation, Action, Adventure, Drama
# 2      0.0148                Animation, Drama, War
# 3      7.8410   Animation, Drama, Fantasy, Romance
# 4      9.6644                     Animation, Drama
#
#                            production_companies_list
# 0  'Studio Ghibli', 'Tokuma Shoten', 'Nippon Tele...
# 1                             'MAPPA', 'Pony Canyon'
# 2                                    'Studio Ghibli'
# 3  'Kyoto Animation', 'ABC Animation', 'Pony Cany...
# 4       'Studio Durian', 'avex pictures', 'Shueisha'

# %%
tmdb_movies_2d['production_countries'][0]
# Out:
# [{'iso_3166_1': 'JP', 'name': 'Japan'}]

# %%
for i, row in tmdb_movies_2d.iterrows():
    tmdb_movies_2d.loc[i, 'production_countries_list'] = str([g['iso_3166_1'] for g in row['production_countries']])[1:-1].replace('\'', '')

# %%
tmdb_movies_2d.drop(columns=['genres', 'spoken_languages', 'production_companies', 'production_countries'], inplace=True)

# %%
tmdb_movies_3d = pd.DataFrame(tmdb_3d)

# %%
tmdb_movies_3d = tmdb_movies_3d[['title', 'id', 'genres', 'overview', 'release_date', 'runtime', 'budget', 'revenue', 'origin_country', 'original_language', 'spoken_languages', 'production_companies', 'production_countries', 'vote_average', 'vote_count', 'popularity']]

# %%
tmdb_movies_3d
# Out:
#                                     title       id  \
# 0     Spider-Man: Across the Spider-Verse   569094
# 1       Spider-Man: Into the Spider-Verse   324857
# 2                          The Wild Robot  1184918
# 3                                    Flow   823219
# 4                             Ratatouille     2062
# ...                                   ...      ...
# 2269                               ROACH™   729501
# 2270        Doomed: A Biological Cartoon!   438247
# 2271                 Distracted Blueberry   743540
# 2272                           Animusic 3   737029
# 2273                             Outremer   719147
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 1     [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 2     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 3     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 4     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...                                                 ...
# 2269  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2270                  [{'id': 16, 'name': 'Animation'}]
# 2271                  [{'id': 16, 'name': 'Animation'}]
# 2272  [{'id': 16, 'name': 'Animation'}, {'id': 10402...
# 2273  [{'id': 16, 'name': 'Animation'}, {'id': 14, '...
#
#                                                overview release_date  runtime  \
# 0     After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31      140
# 1     Struggling to find his place in the world whil...   2018-12-06      117
# 2     After a shipwreck, an intelligent robot called...   2024-09-12      102
# 3     A solitary cat, displaced by a great flood, fi...   2024-08-29       85
# 4     Remy, a rat, possesses a palate far more refin...   2007-06-28      111
# ...                                                 ...          ...      ...
# 2269  A young pilot narrowly escapes the destruction...   2022-12-10       31
# 2270  A fake documentary about the life and habits o...   2011-01-30       10
# 2271  Masculine tropes are undone to form a relation...   2019-10-24      273
# 2272  Animusic is a great electronic music experienc...                     0
# 2273  It's a story about a young boy who is afraid o...   2017-09-15        3
#
#          budget    revenue origin_country original_language  \
# 0     100000000  690897910           [US]                en
# 1      90000000  394884133           [US]                en
# 2      78000000  331982078           [US]                en
# 3       3700000   17660107           [LV]                lv
# 4     150000000  623726000           [US]                en
# ...         ...        ...            ...               ...
# 2269       2000          0       [CA, US]                en
# 2270          0          0           [US]                en
# 2271          0          0           [CA]                fr
# 2272     223123          0           [US]                en
# 2273          0          0           [US]                en
#
#                                        spoken_languages  \
# 0     [{'english_name': 'English', 'iso_639_1': 'en'...
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...
# 3     [{'english_name': 'No Language', 'iso_639_1': ...
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                 ...
# 2269  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2270                                                 []
# 2271  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 2272                                                 []
# 2273  [{'english_name': 'No Language', 'iso_639_1': ...
#
#                                    production_companies  \
# 0     [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
# 1     [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
# 2     [{'id': 521, 'logo_path': '/3BPX5VGBov8SDqTV7w...
# 3     [{'id': 153335, 'logo_path': '/bEsO7l12cRGAY25...
# 4     [{'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUH...
# ...                                                 ...
# 2269  [{'id': 123937, 'logo_path': None, 'name': 'sc...
# 2270  [{'id': 158198, 'logo_path': None, 'name': 'El...
# 2271                                                 []
# 2272  [{'id': 161095, 'logo_path': '/A4j2XOW7wG0Ip2y...
# 2273  [{'id': 71552, 'logo_path': '/hmFPR24kEVCPi6A4...
#
#                                    production_countries  vote_average  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...         8.332
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...         8.393
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...         8.305
# 3     [{'iso_3166_1': 'LV', 'name': 'Latvia'}, {'iso...         8.084
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...         7.838
# ...                                                 ...           ...
# 2269           [{'iso_3166_1': 'CA', 'name': 'Canada'}]         0.000
# 2270            [{'iso_3166_1': 'ES', 'name': 'Spain'}]         0.000
# 2271           [{'iso_3166_1': 'CA', 'name': 'Canada'}]         0.000
# 2272  [{'iso_3166_1': 'US', 'name': 'United States o...         0.000
# 2273           [{'iso_3166_1': 'FR', 'name': 'France'}]         0.000
#
#       vote_count  popularity
# 0           8484     28.9949
# 1          17105     23.6672
# 2           5949     28.6254
# 3           2760     19.2123
# 4          18370     13.9543
# ...          ...         ...
# 2269           0      0.5473
# 2270           0      0.0505
# 2271           0      0.0256
# 2272           0      0.0409
# 2273           0      0.1208
#
# [2274 rows x 16 columns]

# %%
for i, row in tmdb_movies_3d.iterrows():
    tmdb_movies_3d.loc[i, 'genres_list'] = str([g['name'] for g in row['genres']])[1:-1].replace('\'', '')
for i, row in tmdb_movies_3d.iterrows():
    tmdb_movies_3d.loc[i, 'production_companies_list'] = str([g['name'] for g in row['production_companies']])[1:-1]
for i, row in tmdb_movies_3d.iterrows():
    tmdb_movies_3d.loc[i, 'production_countries_list'] = str([g['iso_3166_1'] for g in row['production_countries']])[1:-1].replace('\'', '')
tmdb_movies_3d.drop(columns=['genres', 'spoken_languages', 'production_companies', 'production_countries'], inplace=True)

# %%
tmdb_movies_3d
# Out:
#                                     title       id  \
# 0     Spider-Man: Across the Spider-Verse   569094
# 1       Spider-Man: Into the Spider-Verse   324857
# 2                          The Wild Robot  1184918
# 3                                    Flow   823219
# 4                             Ratatouille     2062
# ...                                   ...      ...
# 2269                               ROACH™   729501
# 2270        Doomed: A Biological Cartoon!   438247
# 2271                 Distracted Blueberry   743540
# 2272                           Animusic 3   737029
# 2273                             Outremer   719147
#
#                                                overview release_date  runtime  \
# 0     After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31      140
# 1     Struggling to find his place in the world whil...   2018-12-06      117
# 2     After a shipwreck, an intelligent robot called...   2024-09-12      102
# 3     A solitary cat, displaced by a great flood, fi...   2024-08-29       85
# 4     Remy, a rat, possesses a palate far more refin...   2007-06-28      111
# ...                                                 ...          ...      ...
# 2269  A young pilot narrowly escapes the destruction...   2022-12-10       31
# 2270  A fake documentary about the life and habits o...   2011-01-30       10
# 2271  Masculine tropes are undone to form a relation...   2019-10-24      273
# 2272  Animusic is a great electronic music experienc...                     0
# 2273  It's a story about a young boy who is afraid o...   2017-09-15        3
#
#          budget    revenue origin_country original_language  vote_average  \
# 0     100000000  690897910           [US]                en         8.332
# 1      90000000  394884133           [US]                en         8.393
# 2      78000000  331982078           [US]                en         8.305
# 3       3700000   17660107           [LV]                lv         8.084
# 4     150000000  623726000           [US]                en         7.838
# ...         ...        ...            ...               ...           ...
# 2269       2000          0       [CA, US]                en         0.000
# 2270          0          0           [US]                en         0.000
# 2271          0          0           [CA]                fr         0.000
# 2272     223123          0           [US]                en         0.000
# 2273          0          0           [US]                en         0.000
#
#       vote_count  popularity                                    genres_list  \
# 0           8484     28.9949  Animation, Action, Adventure, Science Fiction
# 1          17105     23.6672  Animation, Action, Adventure, Science Fiction
# 2           5949     28.6254  Family, Animation, Science Fiction, Adventure
# 3           2760     19.2123          Animation, Adventure, Fantasy, Family
# 4          18370     13.9543             Animation, Comedy, Family, Fantasy
# ...          ...         ...                                            ...
# 2269           0      0.5473                     Science Fiction, Animation
# 2270           0      0.0505                                      Animation
# 2271           0      0.0256                                      Animation
# 2272           0      0.0409                       Animation, Music, Family
# 2273           0      0.1208              Animation, Fantasy, Drama, Family
#
#                               production_companies_list  \
# 0     'Columbia Pictures', 'Sony Pictures Animation'...
# 1     'Columbia Pictures', 'Lord Miller', 'Pascal Pi...
# 2                                'DreamWorks Animation'
# 3     'Dream Well Studio', 'Sacrebleu Productions', ...
# 4                                               'Pixar'
# ...                                                 ...
# 2269                                       'schnüdlbug'
# 2270                                  'El Señor Studio'
# 2271
# 2272                                    'Animusic, LLC'
# 2273                   'Gobelins', "L'école de l'image"
#
#      production_countries_list
# 0                           US
# 1                           US
# 2                           US
# 3                   LV, BE, FR
# 4                           US
# ...                        ...
# 2269                        CA
# 2270                        ES
# 2271                        CA
# 2272                        US
# 2273                        FR
#
# [2274 rows x 15 columns]

# %%
tmdb_movies_2d
# Out:
#                                  title       id  \
# 0                        Spirited Away      129
# 1     Attack on Titan: THE LAST ATTACK  1333100
# 2               Grave of the Fireflies    12477
# 3         Violet Evergarden: The Movie   533514
# 4                            Look Back  1244492
# ...                                ...      ...
# 3085                         Me...Jane   548663
# 3086                      Horizon Blue   745313
# 3087                   The Missing Pig   720636
# 3088        Slocum at Sea with Himself   736019
# 3089                              Nova   744009
#
#                                                overview release_date  runtime  \
# 0     A young girl, Chihiro, becomes trapped in a st...   2001-07-20      125
# 1     A colossal-sized omnibus film bringing togethe...   2024-03-20      145
# 2     In the final months of World War II, 14-year-o...   1988-04-16       89
# 3     As the world moves on from the war and technol...   2020-09-18      140
# 4     Popular, outgoing Fujino is celebrated by her ...   2024-06-28       58
# ...                                                 ...          ...      ...
# 3085  Patrick McDonnell tells the story of the young...   2015-01-10        9
# 3086  The latest from Hiroshi Harada, an adaptation ...   2020-04-25      112
# 3087  A mysterious pig disappearance brings chaos to...   2018-09-28        4
# 3088  I was a self-taught sailor of marginal skills ...   2015-09-10      123
# 3089  A young astronaut works in solitude on a space...   2020-07-30        5
#
#         budget    revenue origin_country original_language  vote_average  \
# 0     19000000  274925095           [JP]                ja         8.500
# 1            0   21525687           [JP]                ja         8.736
# 2      3700000     842132           [JP]                ja         8.400
# 3            0   20339624           [JP]                ja         8.287
# 4            0   12648664           [JP]                ja         8.000
# ...        ...        ...            ...               ...           ...
# 3085         0          0           [US]                en         0.000
# 3086         0          0           [JP]                ja         0.000
# 3087         0          0           [GB]                en         0.000
# 3088         0          0           [US]                en         0.000
# 3089         0          0           [US]                en         0.000
#
#       vote_count  popularity                                genres_list  \
# 0          18194     35.0613                 Animation, Family, Fantasy
# 1            184      6.8777        Animation, Action, Adventure, Drama
# 2           6473      0.0148                      Animation, Drama, War
# 3            501      7.8410         Animation, Drama, Fantasy, Romance
# 4            525      9.6644                           Animation, Drama
# ...          ...         ...                                        ...
# 3085           0      0.1938                          Family, Animation
# 3086           0      0.2621                           Drama, Animation
# 3087           0      0.1125                          Comedy, Animation
# 3088           0      0.0363                                  Animation
# 3089           0      0.0454  Animation, Drama, Science Fiction, Horror
#
#                               production_companies_list  \
# 0     'Studio Ghibli', 'Tokuma Shoten', 'Nippon Tele...
# 1                                'MAPPA', 'Pony Canyon'
# 2                                       'Studio Ghibli'
# 3     'Kyoto Animation', 'ABC Animation', 'Pony Cany...
# 4          'Studio Durian', 'avex pictures', 'Shueisha'
# ...                                                 ...
# 3085   'Weston Woods Studios', 'Scholastic Productions'
# 3086                                         'Kiryûkan'
# 3087
# 3088
# 3089
#
#      production_countries_list
# 0                           JP
# 1                           JP
# 2                           JP
# 3                           JP
# 4                           JP
# ...                        ...
# 3085                        US
# 3086                        JP
# 3087                        GB
# 3088
# 3089
#
# [3090 rows x 15 columns]

# %%
crew = tmdb.Movies(129).credits()['crew']

# %%
[d['name'] for d in crew if d['job'] == 'Director'][0]
# Out:
# 'Hayao Miyazaki'

# %%
for i, row in tmdb_movies_2d.iterrows():
    crew = tmdb.Movies(row['id']).credits()['crew']
    tmdb_movies_2d.loc[i, 'director'] = str([d['name'] for d in crew if d['job'] == 'Director'])[1:-1].replace('\'', '')

# %%
for i, row in tmdb_movies_3d.iterrows():
    crew = tmdb.Movies(row['id']).credits()['crew']
    tmdb_movies_3d.loc[i, 'director'] = str([d['name'] for d in crew if d['job'] == 'Director'])[1:-1].replace('\'', '')

# %%
tmdb_movies_3d
# Out:
#                                     title       id  \
# 0     Spider-Man: Across the Spider-Verse   569094
# 1       Spider-Man: Into the Spider-Verse   324857
# 2                          The Wild Robot  1184918
# 3                                    Flow   823219
# 4                             Ratatouille     2062
# ...                                   ...      ...
# 2269                               ROACH™   729501
# 2270        Doomed: A Biological Cartoon!   438247
# 2271                 Distracted Blueberry   743540
# 2272                           Animusic 3   737029
# 2273                             Outremer   719147
#
#                                                overview release_date  runtime  \
# 0     After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31      140
# 1     Struggling to find his place in the world whil...   2018-12-06      117
# 2     After a shipwreck, an intelligent robot called...   2024-09-12      102
# 3     A solitary cat, displaced by a great flood, fi...   2024-08-29       85
# 4     Remy, a rat, possesses a palate far more refin...   2007-06-28      111
# ...                                                 ...          ...      ...
# 2269  A young pilot narrowly escapes the destruction...   2022-12-10       31
# 2270  A fake documentary about the life and habits o...   2011-01-30       10
# 2271  Masculine tropes are undone to form a relation...   2019-10-24      273
# 2272  Animusic is a great electronic music experienc...                     0
# 2273  It's a story about a young boy who is afraid o...   2017-09-15        3
#
#          budget    revenue origin_country original_language  vote_average  \
# 0     100000000  690897910           [US]                en         8.332
# 1      90000000  394884133           [US]                en         8.393
# 2      78000000  331982078           [US]                en         8.305
# 3       3700000   17660107           [LV]                lv         8.084
# 4     150000000  623726000           [US]                en         7.838
# ...         ...        ...            ...               ...           ...
# 2269       2000          0       [CA, US]                en         0.000
# 2270          0          0           [US]                en         0.000
# 2271          0          0           [CA]                fr         0.000
# 2272     223123          0           [US]                en         0.000
# 2273          0          0           [US]                en         0.000
#
#       vote_count  popularity                                    genres_list  \
# 0           8484     28.9949  Animation, Action, Adventure, Science Fiction
# 1          17105     23.6672  Animation, Action, Adventure, Science Fiction
# 2           5949     28.6254  Family, Animation, Science Fiction, Adventure
# 3           2760     19.2123          Animation, Adventure, Fantasy, Family
# 4          18370     13.9543             Animation, Comedy, Family, Fantasy
# ...          ...         ...                                            ...
# 2269           0      0.5473                     Science Fiction, Animation
# 2270           0      0.0505                                      Animation
# 2271           0      0.0256                                      Animation
# 2272           0      0.0409                       Animation, Music, Family
# 2273           0      0.1208              Animation, Fantasy, Drama, Family
#
#                               production_companies_list  \
# 0     'Columbia Pictures', 'Sony Pictures Animation'...
# 1     'Columbia Pictures', 'Lord Miller', 'Pascal Pi...
# 2                                'DreamWorks Animation'
# 3     'Dream Well Studio', 'Sacrebleu Productions', ...
# 4                                               'Pixar'
# ...                                                 ...
# 2269                                       'schnüdlbug'
# 2270                                  'El Señor Studio'
# 2271
# 2272                                    'Animusic, LLC'
# 2273                   'Gobelins', "L'école de l'image"
#
#      production_countries_list  \
# 0                           US
# 1                           US
# 2                           US
# 3                   LV, BE, FR
# 4                           US
# ...                        ...
# 2269                        CA
# 2270                        ES
# 2271                        CA
# 2272                        US
# 2273                        FR
#
#                                                director
# 0     Kemp Powers, Justin K. Thompson, Joaquim Dos S...
# 1         Bob Persichetti, Peter Ramsey, Rodney Rothman
# 2                                         Chris Sanders
# 3                                      Gints Zilbalodis
# 4                                             Brad Bird
# ...                                                 ...
# 2269                                         schnüdlbug
# 2270                             Guillermo García Carsí
# 2271                                        Barry Doupé
# 2272                        David Crognale, Wayne Lytle
# 2273                       Hadrien Bonnet, Adrien Calle
#
# [2274 rows x 16 columns]

# %%
tmdb_movies_2d.release_date = pd.to_datetime(tmdb_movies_2d.release_date)

# %%
tmdb_movies_3d.release_date = pd.to_datetime(tmdb_movies_3d.release_date)

# %%
tmdb_movies_3d['release_year'] = tmdb_movies_3d.release_date.dt.year

# %%
tmdb_movies_2d['release_year'] = tmdb_movies_2d.release_date.dt.year

# %%
tmdb_movies_2d['release_month'] = tmdb_movies_2d.release_date.dt.month

# %%
tmdb_movies_3d['release_month'] = tmdb_movies_3d.release_date.dt.month

# %%
tmdb_movies_3d['release_weekday'] = tmdb_movies_3d.release_date.dt.strftime('%A')

# %%
tmdb_movies_2d['release_weekday'] = tmdb_movies_2d.release_date.dt.strftime('%A')

# %%
tmdb_movies_2d['release_weekday_num'] = tmdb_movies_2d.release_date.dt.weekday

# %%
tmdb_movies_3d['release_weekday_num'] = tmdb_movies_3d.release_date.dt.weekday

# %%
tmdb_movies_3d['origin_country'] = tmdb_movies_3d['origin_country'].astype(str).str[1:-1].str.replace('\'', '')

# %%
tmdb_movies_2d['origin_country'] = tmdb_movies_2d['origin_country'].astype(str).str[1:-1].str.replace('\'', '')

# %%
tmdb_movies_2d.to_csv('TMDB_2D_Movies.csv')

# %%
tmdb_movies_3d.to_csv('TMDB_3D_Movies.csv')

# %%
tmdb_movies_3d = pd.read_csv('TMDB_3D_Movies.csv')

# %%
tmdb_movies_3d.drop(columns=['Unnamed: 0'], inplace=True)

# %%
tmdb_movies_3d
# Out:
#                                     title       id  \
# 0     Spider-Man: Across the Spider-Verse   569094
# 1       Spider-Man: Into the Spider-Verse   324857
# 2                          The Wild Robot  1184918
# 3                                    Flow   823219
# 4                             Ratatouille     2062
# ...                                   ...      ...
# 2269                               ROACH™   729501
# 2270        Doomed: A Biological Cartoon!   438247
# 2271                 Distracted Blueberry   743540
# 2272                           Animusic 3   737029
# 2273                             Outremer   719147
#
#                                                overview release_date  runtime  \
# 0     After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31      140
# 1     Struggling to find his place in the world whil...   2018-12-06      117
# 2     After a shipwreck, an intelligent robot called...   2024-09-12      102
# 3     A solitary cat, displaced by a great flood, fi...   2024-08-29       85
# 4     Remy, a rat, possesses a palate far more refin...   2007-06-28      111
# ...                                                 ...          ...      ...
# 2269  A young pilot narrowly escapes the destruction...   2022-12-10       31
# 2270  A fake documentary about the life and habits o...   2011-01-30       10
# 2271  Masculine tropes are undone to form a relation...   2019-10-24      273
# 2272  Animusic is a great electronic music experienc...          NaN        0
# 2273  It's a story about a young boy who is afraid o...   2017-09-15        3
#
#          budget    revenue origin_country original_language  vote_average  \
# 0     100000000  690897910             US                en         8.332
# 1      90000000  394884133             US                en         8.393
# 2      78000000  331982078             US                en         8.305
# 3       3700000   17660107             LV                lv         8.084
# 4     150000000  623726000             US                en         7.838
# ...         ...        ...            ...               ...           ...
# 2269       2000          0         CA, US                en         0.000
# 2270          0          0             US                en         0.000
# 2271          0          0             CA                fr         0.000
# 2272     223123          0             US                en         0.000
# 2273          0          0             US                en         0.000
#
#       vote_count  popularity                                    genres_list  \
# 0           8484     28.9949  Animation, Action, Adventure, Science Fiction
# 1          17105     23.6672  Animation, Action, Adventure, Science Fiction
# 2           5949     28.6254  Family, Animation, Science Fiction, Adventure
# 3           2760     19.2123          Animation, Adventure, Fantasy, Family
# 4          18370     13.9543             Animation, Comedy, Family, Fantasy
# ...          ...         ...                                            ...
# 2269           0      0.5473                     Science Fiction, Animation
# 2270           0      0.0505                                      Animation
# 2271           0      0.0256                                      Animation
# 2272           0      0.0409                       Animation, Music, Family
# 2273           0      0.1208              Animation, Fantasy, Drama, Family
#
#                               production_companies_list  \
# 0     'Columbia Pictures', 'Sony Pictures Animation'...
# 1     'Columbia Pictures', 'Lord Miller', 'Pascal Pi...
# 2                                'DreamWorks Animation'
# 3     'Dream Well Studio', 'Sacrebleu Productions', ...
# 4                                               'Pixar'
# ...                                                 ...
# 2269                                       'schnüdlbug'
# 2270                                  'El Señor Studio'
# 2271                                                NaN
# 2272                                    'Animusic, LLC'
# 2273                   'Gobelins', "L'école de l'image"
#
#      production_countries_list  \
# 0                           US
# 1                           US
# 2                           US
# 3                   LV, BE, FR
# 4                           US
# ...                        ...
# 2269                        CA
# 2270                        ES
# 2271                        CA
# 2272                        US
# 2273                        FR
#
#                                                director  release_year  \
# 0     Kemp Powers, Justin K. Thompson, Joaquim Dos S...        2023.0
# 1         Bob Persichetti, Peter Ramsey, Rodney Rothman        2018.0
# 2                                         Chris Sanders        2024.0
# 3                                      Gints Zilbalodis        2024.0
# 4                                             Brad Bird        2007.0
# ...                                                 ...           ...
# 2269                                         schnüdlbug        2022.0
# 2270                             Guillermo García Carsí        2011.0
# 2271                                        Barry Doupé        2019.0
# 2272                        David Crognale, Wayne Lytle           NaN
# 2273                       Hadrien Bonnet, Adrien Calle        2017.0
#
#       release_month release_weekday  release_weekday_num
# 0               5.0       Wednesday                  2.0
# 1              12.0        Thursday                  3.0
# 2               9.0        Thursday                  3.0
# 3               8.0        Thursday                  3.0
# 4               6.0        Thursday                  3.0
# ...             ...             ...                  ...
# 2269           12.0        Saturday                  5.0
# 2270            1.0          Sunday                  6.0
# 2271           10.0        Thursday                  3.0
# 2272            NaN             NaN                  NaN
# 2273            9.0          Friday                  4.0
#
# [2274 rows x 20 columns]

# %%
tmdb_movies_3d['genres_list'].str.split(',')
# Out:
# 0       [Animation,  Action,  Adventure,  Science Fict...
# 1       [Animation,  Action,  Adventure,  Science Fict...
# 2       [Family,  Animation,  Science Fiction,  Advent...
# 3              [Animation,  Adventure,  Fantasy,  Family]
# 4                 [Animation,  Comedy,  Family,  Fantasy]
#                               ...
# 2269                        [Science Fiction,  Animation]
# 2270                                          [Animation]
# 2271                                          [Animation]
# 2272                         [Animation,  Music,  Family]
# 2273               [Animation,  Fantasy,  Drama,  Family]
# Name: genres_list, Length: 2274, dtype: object

# %%
genres = []
for g in tmdb_movies_3d['genres_list'].str.split(','):
    if type(g) is list:
        genres += g
    else:
        print(g)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
genres = [g.strip() for g in genres]

# %%
pd.Series(genres).value_counts()
# Out:
# Animation          1852
# Family              832
# Comedy              730
# Adventure           634
# Fantasy             487
# Science Fiction     432
# Action              397
# Drama               192
# Horror              172
# Music               104
# Thriller             92
# Documentary          74
# TV Movie             57
# Romance              51
# Mystery              43
# Crime                31
# History              29
# War                  27
# Western               5
# Name: count, dtype: int64

# %%
tmdb_movies_3d['release_weekday'].value_counts()
# Out:
# release_weekday
# Friday       520
# Thursday     460
# Tuesday      346
# Wednesday    303
# Saturday     252
# Monday       195
# Sunday       144
# Name: count, dtype: int64

# %%
countries = []
for c in tmdb_movies_3d['production_countries_list'].str.split(','):
    if type(c) is list:
        countries += c

# %%
countries = [c.strip() for c in countries]

# %%
country_counts_3d = pd.Series(countries).value_counts().reset_index()

# %%
country_counts_3d
# Out:
#    index  count
# 0     US   1138
# 1     FR    259
# 2     CA    164
# 3     JP    150
# 4     GB    136
# ..   ...    ...
# 65    GR      1
# 66    AL      1
# 67    SA      1
# 68    AF      1
# 69    PK      1
#
# [70 rows x 2 columns]

# %%
country_codes=pd.read_csv('country_codes.csv')

# %%
country_counts_3d = pd.merge(country_counts_3d, country_codes, left_on='index', right_on='alpha-2', how='left')[['name', 'alpha-2', 'count']]

# %%
country_counts_3d.head(50)
# Out:
#                                                  name alpha-2  count
# 0                            United States of America      US   1138
# 1                                              France      FR    259
# 2                                              Canada      CA    164
# 3                                               Japan      JP    150
# 4   United Kingdom of Great Britain and Northern I...      GB    136
# 5                                               China      CN    117
# 6                                             Germany      DE     79
# 7                                               Spain      ES     52
# 8                                  Korea, Republic of      KR     40
# 9                                               India      IN     39
# 10                                            Belgium      BE     36
# 11                                          Australia      AU     29
# 12                                            Denmark      DK     28
# 13                                          Hong Kong      HK     24
# 14                                 Russian Federation      RU     24
# 15                                              Italy      IT     19
# 16                                             Brazil      BR     19
# 17                                           Malaysia      MY     18
# 18                        Netherlands, Kingdom of the      NL     16
# 19                                          Indonesia      ID     14
# 20                                            Finland      FI     14
# 21                                            Ireland      IE     14
# 22                                             Norway      NO     11
# 23                                          Argentina      AR      9
# 24                          Taiwan, Province of China      TW      8
# 25                                            Czechia      CZ      8
# 26                                           Thailand      TH      7
# 27                                             Mexico      MX      7
# 28                                       South Africa      ZA      7
# 29                                           Bulgaria      BG      7
# 30                                        Switzerland      CH      7
# 31                                             Latvia      LV      6
# 32                                         Luxembourg      LU      6
# 33                                             Poland      PL      6
# 34                                             Sweden      SE      5
# 35                                          Singapore      SG      5
# 36                                           Slovakia      SK      5
# 37                                        New Zealand      NZ      4
# 38                                             Israel      IL      3
# 39                                            Iceland      IS      3
# 40                                            Croatia      HR      3
# 41                                              Chile      CL      3
# 42                                              Qatar      QA      2
# 43                                                NaN     NaN      2
# 44                                 Dominican Republic      DO      2
# 45                               United Arab Emirates      AE      2
# 46                                            Nigeria      NG      2
# 47                                            Hungary      HU      2
# 48                                            Estonia      EE      2
# 49                                           Colombia      CO      2

# %%
tmdb_movies_3d['production_companies_list']
# Out:
# 0       'Columbia Pictures', 'Sony Pictures Animation'...
# 1       'Columbia Pictures', 'Lord Miller', 'Pascal Pi...
# 2                                  'DreamWorks Animation'
# 3       'Dream Well Studio', 'Sacrebleu Productions', ...
# 4                                                 'Pixar'
#                               ...
# 2269                                         'schnüdlbug'
# 2270                                    'El Señor Studio'
# 2271                                                  NaN
# 2272                                      'Animusic, LLC'
# 2273                     'Gobelins', "L'école de l'image"
# Name: production_companies_list, Length: 2274, dtype: object

# %%
import shlex

# %%
import re

# %%
type(tmdb_movies_3d['production_companies_list'][0])
# Out:
# str

# %%
companies = []
for i, row in tmdb_movies_3d.iterrows():
    if type(row['production_companies_list']) is str:
        companies += re.findall(r"\'(.*?)\',?", row['production_companies_list'])

# %%
tmdb_movies_3d['profit'] = tmdb_movies_3d['revenue'] - tmdb_movies_3d['budget']

# %%
tmdb_movies_3d.genres_list.fillna(False, inplace=True)

# %%
tmdb_movies_3d_ani = tmdb_movies_3d[tmdb_movies_3d.genres_list.str.contains('Animation', na=False)]

# %%
tmdb_movies_3d_ani.reset_index(drop=True, inplace=True)

# %%
tmdb_movies_3d_ani.to_csv('TMDB_3D_Movies_Ani.csv')

# %%
cast_3d = []
crew_3d = []

# %%
cast = tmdb.Movies(129).credits()['cast']

# %%
[dict({'movie_id': 129}, **m) for m in cast]
# Out:
# [{'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 19587,
#   'known_for_department': 'Acting',
#   'name': 'Rumi Hiiragi',
#   'original_name': '柊瑠美',
#   'popularity': 1.8797,
#   'profile_path': '/nTKM4GgfkrZvAOFL55uhEuckt7M.jpg',
#   'cast_id': 3,
#   'character': 'Chihiro (voice)',
#   'credit_id': '52fe421bc3a36847f8004a97',
#   'order': 0},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 19588,
#   'known_for_department': 'Acting',
#   'name': 'Miyu Irino',
#   'original_name': '入野自由',
#   'popularity': 2.7184,
#   'profile_path': '/8qEEhHUObNvGQr4e6eqLu5z4qTz.jpg',
#   'cast_id': 4,
#   'character': 'Haku (voice)',
#   'credit_id': '52fe421bc3a36847f8004a9b',
#   'order': 1},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 19589,
#   'known_for_department': 'Acting',
#   'name': 'Mari Natsuki',
#   'original_name': '夏木マリ',
#   'popularity': 1.8964,
#   'profile_path': '/MIFzUc77Sx57FQOZsoiGWEbpH2.jpg',
#   'cast_id': 5,
#   'character': 'Yubaba / Zeniba (voice)',
#   'credit_id': '52fe421bc3a36847f8004a9f',
#   'order': 2},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 19590,
#   'known_for_department': 'Acting',
#   'name': 'Takashi Naito',
#   'original_name': '内藤剛志',
#   'popularity': 1.6895,
#   'profile_path': '/xwsm0ygjG79jLIogutwo6r64igy.jpg',
#   'cast_id': 6,
#   'character': 'Father (voice)',
#   'credit_id': '52fe421bc3a36847f8004aa3',
#   'order': 3},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 19591,
#   'known_for_department': 'Acting',
#   'name': 'Yasuko Sawaguchi',
#   'original_name': '沢口靖子',
#   'popularity': 1.7561,
#   'profile_path': '/rWspusb13VeJowmctnniXYYTcqq.jpg',
#   'cast_id': 7,
#   'character': 'Mother (voice)',
#   'credit_id': '52fe421bc3a36847f8004aa7',
#   'order': 4},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 19592,
#   'known_for_department': 'Acting',
#   'name': 'Tatsuya Gashûin',
#   'original_name': '我修院達也',
#   'popularity': 1.5732,
#   'profile_path': '/fLqIdkShknsJmZy4EfBWuWyHN4C.jpg',
#   'cast_id': 8,
#   'character': 'Aogaeru (voice)',
#   'credit_id': '52fe421bc3a36847f8004aab',
#   'order': 5},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 225730,
#   'known_for_department': 'Acting',
#   'name': 'Ryunosuke Kamiki',
#   'original_name': '神木隆之介',
#   'popularity': 2.4378,
#   'profile_path': '/ut7ewXjdgUmgkhJ1EtbOo9tbc7s.jpg',
#   'cast_id': 30,
#   'character': 'Boh (voice)',
#   'credit_id': '52fe421bc3a36847f8004b17',
#   'order': 6},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 19594,
#   'known_for_department': 'Acting',
#   'name': 'Yumi Tamai',
#   'original_name': '玉井夕海',
#   'popularity': 0.6027,
#   'profile_path': '/x9Td7e5F21cK9S1FCkobfqiJZ1c.jpg',
#   'cast_id': 10,
#   'character': 'Rin (voice)',
#   'credit_id': '52fe421bc3a36847f8004aaf',
#   'order': 7},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 40450,
#   'known_for_department': 'Acting',
#   'name': 'Yo Oizumi',
#   'original_name': '大泉洋',
#   'popularity': 1.8674,
#   'profile_path': '/qw5KLuww2AEAk6JEssEkJY3wBn1.jpg',
#   'cast_id': 25,
#   'character': 'Bandai Frog (voice)',
#   'credit_id': '52fe421bc3a36847f8004b07',
#   'order': 8},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 554423,
#   'known_for_department': 'Acting',
#   'name': 'Koba Hayashi',
#   'original_name': 'はやし・こば',
#   'popularity': 0.3344,
#   'profile_path': '/ceQ58tRgqMZ9gePHg8xkKarZm0M.jpg',
#   'cast_id': 26,
#   'character': 'River Spirit (voice)',
#   'credit_id': '52fe421bc3a36847f8004b0b',
#   'order': 9},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 20334,
#   'known_for_department': 'Acting',
#   'name': 'Tsunehiko Kamijô',
#   'original_name': '上條恒彦',
#   'popularity': 1.2841,
#   'profile_path': '/v2poQi0qYEWdTaMf2pVTWmcdwZp.jpg',
#   'cast_id': 27,
#   'character': 'Chichiyaku (voice)',
#   'credit_id': '52fe421bc3a36847f8004b0f',
#   'order': 10},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 544088,
#   'known_for_department': 'Acting',
#   'name': 'Takehiko Ono',
#   'original_name': '小野武彦',
#   'popularity': 1.4311,
#   'profile_path': '/8gcT8znk0l3YVZKvL7eVxYublTl.jpg',
#   'cast_id': 28,
#   'character': 'Aniyaku (voice)',
#   'credit_id': '52fe421bc3a36847f8004b13',
#   'order': 11},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 119243,
#   'known_for_department': 'Acting',
#   'name': 'Bunta Sugawara',
#   'original_name': '菅原文太',
#   'popularity': 2.0312,
#   'profile_path': '/lHPLlP8zNwGMmcUI8rGks5vp8Vn.jpg',
#   'cast_id': 31,
#   'character': 'Kamaji (voice)',
#   'credit_id': '52fe421bc3a36847f8004b1b',
#   'order': 12},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 1530058,
#   'known_for_department': 'Production',
#   'name': 'Shigeru Wakita',
#   'original_name': '脇田茂',
#   'popularity': 0.2235,
#   'profile_path': '/6iFm0U12QGmKDizbn08WqO1WXCU.jpg',
#   'cast_id': 97,
#   'character': '(voice)',
#   'credit_id': '5fb05ded3a48c5003c7d7a18',
#   'order': 13},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 1243817,
#   'known_for_department': 'Acting',
#   'name': 'Shirou Saitou',
#   'original_name': '斎藤志郎',
#   'popularity': 0.984,
#   'profile_path': '/yJSrzULl9EuXI25E8REdIPY1Lkm.jpg',
#   'cast_id': 98,
#   'character': '(voice)',
#   'credit_id': '5fb05df6c15f89003f838bc5',
#   'order': 14},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 1608518,
#   'known_for_department': 'Acting',
#   'name': 'Michiko Yamamoto',
#   'original_name': '山本道子',
#   'popularity': 0.3935,
#   'profile_path': '/cV4irDcmf4biTjTGaU1oPmFO7KR.jpg',
#   'cast_id': 99,
#   'character': '(voice)',
#   'credit_id': '5fb05e02a22d3e004103aaf6',
#   'order': 15},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2844828,
#   'known_for_department': 'Acting',
#   'name': 'Keiko Tsukamoto',
#   'original_name': 'つかもと景子',
#   'popularity': 0.4009,
#   'profile_path': '/50AMEWXz2HUt3RFKoEuJk3Xl84k.jpg',
#   'cast_id': 100,
#   'character': '(voice)',
#   'credit_id': '5fb05e0b5ed962003e107c9c',
#   'order': 16},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 554612,
#   'known_for_department': 'Acting',
#   'name': 'Akio Nakamura',
#   'original_name': '中村彰男',
#   'popularity': 1.0632,
#   'profile_path': '/z7GzSvEkb3vhA77FFS6JnkpEEbv.jpg',
#   'cast_id': 101,
#   'character': 'Kaonashi (voice)',
#   'credit_id': '5fb05e14b54002003f597b15',
#   'order': 17},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856717,
#   'known_for_department': 'Acting',
#   'name': 'Shinji Tokumaru',
#   'original_name': '得丸伸二',
#   'popularity': 0.1078,
#   'profile_path': '/rYRs9Fbe5Cd0bJwxbM4bZp5MrKX.jpg',
#   'cast_id': 102,
#   'character': '(voice)',
#   'credit_id': '5fb05e1f9ca75900404b384b',
#   'order': 18},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 554367,
#   'known_for_department': 'Acting',
#   'name': 'Kaori Yamagata',
#   'original_name': '山像かおり',
#   'popularity': 0.7935,
#   'profile_path': '/bhtFlZCoBxhq1FeNwx7ODNOZ73R.jpg',
#   'cast_id': 103,
#   'character': '(voice)',
#   'credit_id': '5fb05e293a48c5003c7d7a9b',
#   'order': 19},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2023580,
#   'known_for_department': 'Acting',
#   'name': 'Tsuzuki Kayako',
#   'original_name': '都築香弥子',
#   'popularity': 0.5684,
#   'profile_path': '/9lKIm8V4yU3LztYj3B6LlOF9FyN.jpg',
#   'cast_id': 104,
#   'character': '(voice)',
#   'credit_id': '5fb05e33d55e4d003cd049c2',
#   'order': 20},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856718,
#   'known_for_department': 'Acting',
#   'name': 'Masahiro Asano',
#   'original_name': '浅野雅博',
#   'popularity': 0.1515,
#   'profile_path': '/1FczbddfHUGlKg3z3opoV04pBZE.jpg',
#   'cast_id': 105,
#   'character': '(voice)',
#   'credit_id': '5fb05e3cb54002004058bca5',
#   'order': 21},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 0,
#   'id': 2856719,
#   'known_for_department': 'Acting',
#   'name': 'Kazutaka Hayashida',
#   'original_name': 'Kazutaka Hayashida',
#   'popularity': 0.0622,
#   'profile_path': '/qxSLhaJLstgBm9DkWpD5AW4Va8A.jpg',
#   'cast_id': 106,
#   'character': '(voice)',
#   'credit_id': '5fb05e45a22d3e004003380d',
#   'order': 22},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856720,
#   'known_for_department': 'Acting',
#   'name': 'Ikuko Yamamoto',
#   'original_name': '山本郁子',
#   'popularity': 0.4505,
#   'profile_path': '/ybMkOM1ztKz8vHH2SKlMb4RgkZ6.jpg',
#   'cast_id': 107,
#   'character': '(voice)',
#   'credit_id': '5fb05e4e945c20003ee8575e',
#   'order': 23},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856721,
#   'known_for_department': 'Acting',
#   'name': 'Mina Meguro',
#   'original_name': '目黒未奈',
#   'popularity': 0.2353,
#   'profile_path': '/mx1n8cmUTMT0oZH4zyqo3zx84MN.jpg',
#   'cast_id': 108,
#   'character': '(voice)',
#   'credit_id': '5fb05e5837b3a9003f015040',
#   'order': 24},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856722,
#   'known_for_department': 'Acting',
#   'name': 'Tetsurô Ishibashi',
#   'original_name': '石橋徹郎',
#   'popularity': 0.1505,
#   'profile_path': '/lMTfxLJEOSNFk0MgpA3RsoqxEdn.jpg',
#   'cast_id': 109,
#   'character': '(voice)',
#   'credit_id': '5fb05e63d8f44e003ef7a213',
#   'order': 25},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856723,
#   'known_for_department': 'Acting',
#   'name': 'Katsutomo Shîbara',
#   'original_name': '椎原克知',
#   'popularity': 0.2282,
#   'profile_path': '/o8Wcta86QK2uHURyDqjTAxEajsj.jpg',
#   'cast_id': 110,
#   'character': '(voice)',
#   'credit_id': '5fb05e75b6cff1003ac3a3cc',
#   'order': 26},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856724,
#   'known_for_department': 'Acting',
#   'name': 'Shinobu Katabuchi',
#   'original_name': '片渕忍',
#   'popularity': 0.1516,
#   'profile_path': '/gYMuEq00H2ESNnSNfGmBNSjld7T.jpg',
#   'cast_id': 111,
#   'character': '(voice)',
#   'credit_id': '5fb05e88626208003eb39c17',
#   'order': 27},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 1241949,
#   'known_for_department': 'Acting',
#   'name': 'Noriko Kitou',
#   'original_name': '鬼頭典子',
#   'popularity': 0.3203,
#   'profile_path': '/hHtABHbBeTHA9ZGF2uX0zyWvS4H.jpg',
#   'cast_id': 112,
#   'character': '(voice)',
#   'credit_id': '5fb05e91945c200041e92f35',
#   'order': 28},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856725,
#   'known_for_department': 'Acting',
#   'name': 'Naoto Kaji',
#   'original_name': '鍛治直人',
#   'popularity': 0.2961,
#   'profile_path': '/6fzuj6fYwrogkJ62sPAp5BMrFMw.jpg',
#   'cast_id': 113,
#   'character': '(voice)',
#   'credit_id': '5fb05e9ad8f44e003ef7a28f',
#   'order': 29},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856726,
#   'known_for_department': 'Acting',
#   'name': 'Yoshitaka Sukegawa',
#   'original_name': 'Yoshitaka Sukegawa',
#   'popularity': 0.0724,
#   'profile_path': '/yahqVr8U7WPySJKULZQFC8qpkMp.jpg',
#   'cast_id': 114,
#   'character': '(voice)',
#   'credit_id': '5fb05ea33a48c5003d7dd8a5',
#   'order': 30},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856727,
#   'known_for_department': 'Acting',
#   'name': 'Aki Tachikawa',
#   'original_name': '太刀川亞希',
#   'popularity': 0.1716,
#   'profile_path': '/yFuE7lgueXvBnrZno6yGgmx17oU.jpg',
#   'cast_id': 115,
#   'character': '(voice)',
#   'credit_id': '5fb05eab3a48c5003f7de71f',
#   'order': 31},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856728,
#   'known_for_department': 'Acting',
#   'name': 'Noriko Yamaya',
#   'original_name': 'Noriko Yamaya',
#   'popularity': 0.0741,
#   'profile_path': '/2mX50DBmijvB5roubhchAECEawR.jpg',
#   'cast_id': 116,
#   'character': '(voice)',
#   'credit_id': '5fb05ebcd8f44e003df6e673',
#   'order': 32},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 2856729,
#   'known_for_department': 'Acting',
#   'name': 'Katsuhisa Matsuo',
#   'original_name': '松尾勝久',
#   'popularity': 0.0737,
#   'profile_path': None,
#   'cast_id': 117,
#   'character': '(voice)',
#   'credit_id': '5fb05ec5d55e4d003dcffb26',
#   'order': 33},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 1921932,
#   'known_for_department': 'Acting',
#   'name': 'Masayuki Kizu',
#   'original_name': '木津誠之',
#   'popularity': 0.207,
#   'profile_path': None,
#   'cast_id': 118,
#   'character': '(voice)',
#   'credit_id': '5fb05ecfa22d3e003f04280f',
#   'order': 34},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856730,
#   'known_for_department': 'Acting',
#   'name': 'Yôko Ôno',
#   'original_name': '大野容子',
#   'popularity': 0.1403,
#   'profile_path': '/sn7LgwfIIi9dgAL3DQbSL5omivT.jpg',
#   'cast_id': 119,
#   'character': '(voice)',
#   'credit_id': '5fb05ee7945c200040e8da0d',
#   'order': 35},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 0,
#   'id': 2856731,
#   'known_for_department': 'Acting',
#   'name': 'Sachie Azuma',
#   'original_name': 'Sachie Azuma',
#   'popularity': 0.0962,
#   'profile_path': None,
#   'cast_id': 120,
#   'character': '(voice)',
#   'credit_id': '5fb05ef54a4bfc0041b4a98c',
#   'order': 36},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 1039220,
#   'known_for_department': 'Acting',
#   'name': 'Ken Yasuda',
#   'original_name': '安田顕',
#   'popularity': 1.5515,
#   'profile_path': '/mSEnXFHj8MnighBVG0yZdKOVyxI.jpg',
#   'cast_id': 121,
#   'character': 'Oshira-sama (voice)',
#   'credit_id': '5fb05f00b6cff1003ac3a451',
#   'order': 37},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 2,
#   'id': 1251804,
#   'known_for_department': 'Acting',
#   'name': 'Shigeyuki Totsugi',
#   'original_name': '戸次重幸',
#   'popularity': 1.0299,
#   'profile_path': '/pK3B7H4qrzLy7nKr0lFKfqNRq91.jpg',
#   'cast_id': 122,
#   'character': 'Kashira (voice)',
#   'credit_id': '5fb05f115ed962003d10f086',
#   'order': 38},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2463593,
#   'known_for_department': 'Acting',
#   'name': 'Mayumi Saco',
#   'original_name': '佐古真弓',
#   'popularity': 0.5983,
#   'profile_path': '/quaubRxGvU9IIaq2Nf7ejO3m5g2.jpg',
#   'cast_id': 123,
#   'character': '(voice)',
#   'credit_id': '5fb05f1aec4552003ff6eb2a',
#   'order': 39},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856733,
#   'known_for_department': 'Acting',
#   'name': 'Sonoko Soeda',
#   'original_name': '添田園子',
#   'popularity': 0.1185,
#   'profile_path': '/xE6oVD5871XzK07zmQbEhqWpaaD.jpg',
#   'cast_id': 124,
#   'character': '(voice)',
#   'credit_id': '5fb05f289ca75900404b3a2c',
#   'order': 40},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856734,
#   'known_for_department': 'Acting',
#   'name': 'Akiko Tomihira',
#   'original_name': 'Akiko Tomihira',
#   'popularity': 0.1223,
#   'profile_path': None,
#   'cast_id': 125,
#   'character': '(voice)',
#   'credit_id': '5fb05f31945c200041e93017',
#   'order': 41},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856735,
#   'known_for_department': 'Acting',
#   'name': 'Minako Masuda',
#   'original_name': 'Minako Masuda',
#   'popularity': 0.1649,
#   'profile_path': None,
#   'cast_id': 126,
#   'character': '(voice)',
#   'credit_id': '5fb05f3d6dc6c000422a6701',
#   'order': 42},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856736,
#   'known_for_department': 'Acting',
#   'name': 'Orika Ono',
#   'original_name': 'Orika Ono',
#   'popularity': 0.1277,
#   'profile_path': None,
#   'cast_id': 127,
#   'character': '(voice)',
#   'credit_id': '5fb05f469ca759003f4a80ab',
#   'order': 43},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856737,
#   'known_for_department': 'Acting',
#   'name': 'Rina Yamada',
#   'original_name': '山田里奈',
#   'popularity': 0.252,
#   'profile_path': '/baVr49M1u7bcmEMD4NrP84aGzX0.jpg',
#   'cast_id': 128,
#   'character': '(voice)',
#   'credit_id': '5fb05f4fdb154f003e49ed31',
#   'order': 44},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 0,
#   'id': 2856738,
#   'known_for_department': 'Acting',
#   'name': 'Miwa Takachi',
#   'original_name': 'Miwa Takachi',
#   'popularity': 0.1044,
#   'profile_path': None,
#   'cast_id': 129,
#   'character': '(voice)',
#   'credit_id': '5fb05f583a48c5003c7d7b4d',
#   'order': 45},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 0,
#   'id': 1887860,
#   'known_for_department': 'Acting',
#   'name': 'Hiromi Takeuchi',
#   'original_name': 'Hiromi Takeuchi',
#   'popularity': 0.0808,
#   'profile_path': None,
#   'cast_id': 130,
#   'character': '(voice)',
#   'credit_id': '5fb05f62626208003eb39d1d',
#   'order': 46},
#  {'movie_id': 129,
#   'adult': False,
#   'gender': 1,
#   'id': 2856739,
#   'known_for_department': 'Acting',
#   'name': 'Makiko Oku',
#   'original_name': '奥真紀子',
#   'popularity': 0.2293,
#   'profile_path': None,
#   'cast_id': 131,
#   'character': '(voice)',
#   'credit_id': '5fb05f6a498ef9003f8104e4',
#   'order': 47}]

# %%
tmdb_movies_3d_ani = pd.read_csv('TMDB_3D_Movies_Ani.csv')

# %%
tmdb_movies_3d_ani.head()
# Out:
#    Unnamed: 0                                title       id  \
# 0           0  Spider-Man: Across the Spider-Verse   569094
# 1           1    Spider-Man: Into the Spider-Verse   324857
# 2           2                       The Wild Robot  1184918
# 3           3                                 Flow   823219
# 4           4                          Ratatouille     2062
#
#                                             overview release_date  runtime  \
# 0  After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31      140
# 1  Struggling to find his place in the world whil...   2018-12-06      117
# 2  After a shipwreck, an intelligent robot called...   2024-09-12      102
# 3  A solitary cat, displaced by a great flood, fi...   2024-08-29       85
# 4  Remy, a rat, possesses a palate far more refin...   2007-06-28      111
#
#       budget    revenue origin_country original_language  ...  popularity  \
# 0  100000000  690897910             US                en  ...     28.9949
# 1   90000000  394884133             US                en  ...     23.6672
# 2   78000000  331982078             US                en  ...     28.6254
# 3    3700000   17660107             LV                lv  ...     19.2123
# 4  150000000  623726000             US                en  ...     13.9543
#
#                                      genres_list  \
# 0  Animation, Action, Adventure, Science Fiction
# 1  Animation, Action, Adventure, Science Fiction
# 2  Family, Animation, Science Fiction, Adventure
# 3          Animation, Adventure, Fantasy, Family
# 4             Animation, Comedy, Family, Fantasy
#
#                            production_companies_list  \
# 0  'Columbia Pictures', 'Sony Pictures Animation'...
# 1  'Columbia Pictures', 'Lord Miller', 'Pascal Pi...
# 2                             'DreamWorks Animation'
# 3  'Dream Well Studio', 'Sacrebleu Productions', ...
# 4                                            'Pixar'
#
#   production_countries_list  \
# 0                        US
# 1                        US
# 2                        US
# 3                LV, BE, FR
# 4                        US
#
#                                             director release_year  \
# 0  Kemp Powers, Justin K. Thompson, Joaquim Dos S...       2023.0
# 1      Bob Persichetti, Peter Ramsey, Rodney Rothman       2018.0
# 2                                      Chris Sanders       2024.0
# 3                                   Gints Zilbalodis       2024.0
# 4                                          Brad Bird       2007.0
#
#   release_month  release_weekday  release_weekday_num     profit
# 0           5.0        Wednesday                  2.0  590897910
# 1          12.0         Thursday                  3.0  304884133
# 2           9.0         Thursday                  3.0  253982078
# 3           8.0         Thursday                  3.0   13960107
# 4           6.0         Thursday                  3.0  473726000
#
# [5 rows x 22 columns]

# %%
for i, row in tmdb_movies_3d_ani.iterrows():
    credits = tmdb.Movies(row['id']).credits()
    cast = [dict({'movie_id': row['id']}, **m) for m in credits['cast']]
    crew = [dict({'movie_id': row['id']}, **m) for m in credits['crew']]
    cast_3d += cast
    crew_3d += crew

# %%
cast_3d_df = pd.DataFrame(cast_3d)

# %%
crew_3d_df = pd.DataFrame(crew_3d)

# %%
cast_3d_df.drop(columns=['profile_path'], inplace=True)

# %%
crew_3d_df.drop(columns=['profile_path'], inplace=True)

# %%
cast_3d_df.to_csv('3D_Movies_Cast.csv', index=False)

# %%
crew_3d_df.to_csv('3D_Movies_Crew.csv', index=False)

# %%
tmdb_movies_3d_ani.drop(columns=['Unnamed: 0'], inplace=True)

# %%
tmdb_movies_3d_ani.to_csv('TMDB_3D_Movies_Ani.csv', index=False)

# %%
tmdb_movies_2d = pd.read_csv('TMDB_2D_Movies.csv')

# %%
tmdb_movies_2d.drop(columns=['Unnamed: 0'], inplace=True)

# %%
tmdb_movies_2d.to_csv('TMDB_2D_Movies.csv', index=False)

# %%
tmdb_movies_2d.head()
# Out:
#                               title       id  \
# 0                     Spirited Away      129
# 1  Attack on Titan: THE LAST ATTACK  1333100
# 2            Grave of the Fireflies    12477
# 3      Violet Evergarden: The Movie   533514
# 4                         Look Back  1244492
#
#                                             overview release_date  runtime  \
# 0  A young girl, Chihiro, becomes trapped in a st...   2001-07-20      125
# 1  A colossal-sized omnibus film bringing togethe...   2024-03-20      145
# 2  In the final months of World War II, 14-year-o...   1988-04-16       89
# 3  As the world moves on from the war and technol...   2020-09-18      140
# 4  Popular, outgoing Fujino is celebrated by her ...   2024-06-28       58
#
#      budget    revenue origin_country original_language  vote_average  \
# 0  19000000  274925095             JP                ja         8.500
# 1         0   21525687             JP                ja         8.736
# 2   3700000     842132             JP                ja         8.400
# 3         0   20339624             JP                ja         8.287
# 4         0   12648664             JP                ja         8.000
#
#    vote_count  popularity                          genres_list  \
# 0       18194     35.0613           Animation, Family, Fantasy
# 1         184      6.8777  Animation, Action, Adventure, Drama
# 2        6473      0.0148                Animation, Drama, War
# 3         501      7.8410   Animation, Drama, Fantasy, Romance
# 4         525      9.6644                     Animation, Drama
#
#                            production_companies_list  \
# 0  'Studio Ghibli', 'Tokuma Shoten', 'Nippon Tele...
# 1                             'MAPPA', 'Pony Canyon'
# 2                                    'Studio Ghibli'
# 3  'Kyoto Animation', 'ABC Animation', 'Pony Cany...
# 4       'Studio Durian', 'avex pictures', 'Shueisha'
#
#   production_countries_list           director  release_year  release_month  \
# 0                        JP     Hayao Miyazaki        2001.0            7.0
# 1                        JP   Yuichiro Hayashi        2024.0            3.0
# 2                        JP      Isao Takahata        1988.0            4.0
# 3                        JP    Taichi Ishidate        2020.0            9.0
# 4                        JP  Kiyotaka Oshiyama        2024.0            6.0
#
#   release_weekday  release_weekday_num
# 0          Friday                  4.0
# 1       Wednesday                  2.0
# 2        Saturday                  5.0
# 3          Friday                  4.0
# 4          Friday                  4.0

# %%
cast_2d = []
crew_2d = []

# %%
for i, row in tmdb_movies_2d.iterrows():
    credits = tmdb.Movies(row['id']).credits()
    cast = [dict({'movie_id': row['id']}, **m) for m in credits['cast']]
    crew = [dict({'movie_id': row['id']}, **m) for m in credits['crew']]
    cast_2d += cast
    crew_2d += crew

# %%
cast_2d_df = pd.DataFrame(cast_2d)
crew_2d_df = pd.DataFrame(crew_2d)

# %%
cast_2d_df.drop(columns=['profile_path'], inplace=True)
crew_2d_df.drop(columns=['profile_path'], inplace=True)

# %%
cast_2d_df.to_csv('2D_Movies_Cast.csv', index=False)
crew_2d_df.to_csv('2D_Movies_Crew.csv', index=False)
